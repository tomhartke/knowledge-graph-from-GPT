# %% [markdown]
# # Smart flash cards using LLMs

# %%
import os
import openai # make sure to pip install openai
import re
import json
import numpy as np
import pandas as pd
from collections import Counter
from typing import Any, Optional, Tuple, Dict, List, NamedTuple, Set
import scipy
import time

from pprint import pprint as pprint
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

from basic_utils import *
from initial_card_processing import *
from knowledge_graph import *
from knowledge_graph_querying import *

# %% [markdown]
# ## Process initial flashcards to extract info
# Load flashcards from CSV and create json file with saved meta data

# %%
# process my basic flashcards from online
csv_title = 'my_flash_cards_general' 
verbose=False
cards_df_abstraction_groups = get_cards_df_abstraction_groups_from_front_and_back_csv(csv_title, verbose=verbose)
save_cards_df_to_json(cards_df_abstraction_groups, csv_title + '_cards_df_abstraction_groups')
# Out:
# Card index:  0
# global_tokens_used_for_card_reading:  0
# Total used tokens: 119  for card index  0
# Total used tokens: 157  for card index  1
# Total used tokens: 201  for card index  2
# Total used tokens: 175  for card index  3
# Total used tokens: 150  for card index  4
# Total used tokens: 182  for card index  5
# Total used tokens: 201  for card index  6
# Total used tokens: 147  for card index  7
# Total used tokens: 180  for card index  8
# Total used tokens: 144  for card index  9
# Total used tokens: 126  for card index  10
# Total used tokens: 95  for card index  11
# Total used tokens: 273  for card index  12
# Total used tokens: 135  for card index  13
# Total used tokens: 286  for card index  14
# Total used tokens: 175  for card index  15
# Total used tokens: 218  for card index  16
# Total used tokens: 177  for card index  17
# Total used tokens: 242  for card index  18
# Total used tokens: 172  for card index  19
# Card index:  20
# global_tokens_used_for_card_reading:  3555
# Total used tokens: 222  for card index  20
# Total used tokens: 256  for card index  21
# Total used tokens: 146  for card index  22
# Total used tokens: 158  for card index  23
# Total used tokens: 209  for card index  24
# Total used tokens: 213  for card index  25
# Total used tokens: 304  for card index  26
# Total used tokens: 207  for card index  27
# Total used tokens: 345  for card index  28
# Total used tokens: 259  for card index  29
# Total used tokens: 196  for card index  30
# Total used tokens: 175  for card index  31
# Total used tokens: 149  for card index  32
# Total used tokens: 189  for card index  33
# Total used tokens: 184  for card index  34
# Total used tokens: 146  for card index  35
# Total used tokens: 190  for card index  36
# Total used tokens: 143  for card index  37
# Total used tokens: 148  for card index  38
# Total used tokens: 139  for card index  39
# Card index:  40
# global_tokens_used_for_card_reading:  7533
# Total used tokens: 189  for card index  40
# Total used tokens: 120  for card index  41
# Total used tokens: 166  for card index  42
# Total used tokens: 117  for card index  43
# Total used tokens: 157  for card index  44
# Total used tokens: 198  for card index  45
# Total used tokens: 263  for card index  46
# Total used tokens: 195  for card index  47
# Total used tokens: 146  for card index  48
# Total used tokens: 203  for card index  49
# Total used tokens: 184  for card index  50
# Total used tokens: 199  for card index  51
# Total used tokens: 204  for card index  52
# Total used tokens: 177  for card index  53
# Total used tokens: 177  for card index  54
# Total used tokens: 166  for card index  55
# Total used tokens: 124  for card index  56
# Total used tokens: 115  for card index  57
# Total used tokens: 158  for card index  58
# Total used tokens: 217  for card index  59
# Card index:  60
# global_tokens_used_for_card_reading:  11008
# Total used tokens: 136  for card index  60
# Total used tokens: 156  for card index  61
# Total used tokens: 115  for card index  62
# Total used tokens: 164  for card index  63
# Total used tokens: 223  for card index  64
# Total used tokens: 158  for card index  65
# Total used tokens: 212  for card index  66
# Total used tokens: 257  for card index  67
# Total used tokens: 160  for card index  68
# Total used tokens: 163  for card index  69
# Total used tokens: 407  for card index  70
# Total used tokens: 161  for card index  71
# Total used tokens: 203  for card index  72
# Total used tokens: 191  for card index  73
# Total used tokens: 232  for card index  74
# Total used tokens: 204  for card index  75
# Total used tokens: 143  for card index  76
# Total used tokens: 252  for card index  77
# Total used tokens: 147  for card index  78
# Total used tokens: 158  for card index  79
# Card index:  80
# global_tokens_used_for_card_reading:  14850
# Total used tokens: 185  for card index  80
# Total used tokens: 162  for card index  81
# Total used tokens: 199  for card index  82
# Total used tokens: 180  for card index  83
# Total used tokens: 104  for card index  84
# Total used tokens: 134  for card index  85
# Total used tokens: 220  for card index  86
# Total used tokens: 201  for card index  87
# Total used tokens: 172  for card index  88
# Total used tokens: 162  for card index  89
# Total used tokens: 120  for card index  90
# Total used tokens: 183  for card index  91
# Total used tokens: 205  for card index  92
# Total used tokens: 237  for card index  93
# Total used tokens: 274  for card index  94
# Total used tokens: 195  for card index  95
# Total used tokens: 218  for card index  96
# Total used tokens: 195  for card index  97
# Total used tokens: 154  for card index  98
# Total used tokens: 201  for card index  99
# Card index:  100
# global_tokens_used_for_card_reading:  18551
# Total used tokens: 170  for card index  100
# Total used tokens: 205  for card index  101
# Total used tokens: 214  for card index  102
# Total used tokens: 176  for card index  103
# Total used tokens: 245  for card index  104
# Total used tokens: 133  for card index  105
# Total used tokens: 174  for card index  106
# Total used tokens: 161  for card index  107
# Total used tokens: 190  for card index  108
# Total used tokens: 235  for card index  109
# Total used tokens: 229  for card index  110
# Total used tokens: 165  for card index  111
# Total used tokens: 184  for card index  112
# Total used tokens: 206  for card index  113
# Total used tokens: 121  for card index  114
# Total used tokens: 229  for card index  115
# Total used tokens: 177  for card index  116
# Total used tokens: 147  for card index  117
# Total used tokens: 173  for card index  118
# Total used tokens: 186  for card index  119
# Card index:  120
# global_tokens_used_for_card_reading:  22271
# Total used tokens: 189  for card index  120
# Total used tokens: 232  for card index  121
# Total used tokens: 184  for card index  122
# Total used tokens: 262  for card index  123
# Total used tokens: 205  for card index  124
# Total used tokens: 116  for card index  125
# Total used tokens: 204  for card index  126
# Total used tokens: 251  for card index  127
# Total used tokens: 216  for card index  128
# Total used tokens: 229  for card index  129
# Total used tokens: 129  for card index  130
# Total used tokens: 187  for card index  131
# Total used tokens: 217  for card index  132
# Total used tokens: 229  for card index  133
# Total used tokens: 155  for card index  134
# Total used tokens: 216  for card index  135
# Total used tokens: 358  for card index  136
# Total used tokens: 183  for card index  137
# Total used tokens: 154  for card index  138
# Total used tokens: 145  for card index  139
# Card index:  140
# global_tokens_used_for_card_reading:  26332
# Total used tokens: 171  for card index  140
# Total used tokens: 182  for card index  141
# Total used tokens: 142  for card index  142
# Total used tokens: 137  for card index  143
# Total used tokens: 237  for card index  144
# Total used tokens: 164  for card index  145
# Total used tokens: 122  for card index  146
# Total used tokens: 107  for card index  147
# Total used tokens: 168  for card index  148
# Total used tokens: 154  for card index  149
# Total used tokens: 148  for card index  150
# Total used tokens: 130  for card index  151
# Total used tokens: 156  for card index  152
# Total used tokens: 134  for card index  153
# Total used tokens: 140  for card index  154
# Total used tokens: 172  for card index  155
# Total used tokens: 128  for card index  156
# Total used tokens: 140  for card index  157
# Total used tokens: 225  for card index  158
# Total used tokens: 126  for card index  159
# Card index:  160
# global_tokens_used_for_card_reading:  29415
# Total used tokens: 108  for card index  160
# Total used tokens: 157  for card index  161
# Total used tokens: 202  for card index  162
# Total used tokens: 183  for card index  163
# Total used tokens: 134  for card index  164
# Total used tokens: 160  for card index  165
# Total used tokens: 153  for card index  166
# Total used tokens: 147  for card index  167
# Total used tokens: 183  for card index  168
# Total used tokens: 172  for card index  169
# Total used tokens: 140  for card index  170
# Total used tokens: 148  for card index  171
# Total used tokens: 153  for card index  172
# Total used tokens: 166  for card index  173
# Total used tokens: 146  for card index  174
# Total used tokens: 171  for card index  175
# Total used tokens: 203  for card index  176
# Total used tokens: 156  for card index  177
# Total used tokens: 154  for card index  178
# Total used tokens: 109  for card index  179
# Card index:  180
# global_tokens_used_for_card_reading:  32560
# Total used tokens: 144  for card index  180
# Total used tokens: 362  for card index  181
# Total used tokens: 199  for card index  182
# Total used tokens: 212  for card index  183
# Total used tokens: 178  for card index  184
# Total used tokens: 153  for card index  185
# Total used tokens: 184  for card index  186
# Total used tokens: 237  for card index  187
# Total used tokens: 170  for card index  188
# Total used tokens: 191  for card index  189
# Total used tokens: 182  for card index  190
# Total used tokens: 147  for card index  191
# Total used tokens: 128  for card index  192
# Total used tokens: 299  for card index  193
# Total used tokens: 145  for card index  194
# Total used tokens: 191  for card index  195
# Total used tokens: 122  for card index  196
# Total used tokens: 156  for card index  197
# Total used tokens: 181  for card index  198
# Total used tokens: 156  for card index  199
# Card index:  200
# global_tokens_used_for_card_reading:  36297
# Total used tokens: 217  for card index  200
# Total used tokens: 117  for card index  201
# Total used tokens: 140  for card index  202
# Total used tokens: 128  for card index  203
# Total used tokens: 156  for card index  204
# Total used tokens: 167  for card index  205
# Total used tokens: 129  for card index  206
# Total used tokens: 167  for card index  207
# Total used tokens: 116  for card index  208
# Total used tokens: 279  for card index  209
# Total used tokens: 160  for card index  210
# Total used tokens: 143  for card index  211
# Total used tokens: 281  for card index  212
# Total used tokens: 187  for card index  213
# Total used tokens: 160  for card index  214
# Total used tokens: 132  for card index  215
# Total used tokens: 232  for card index  216
# Total used tokens: 131  for card index  217
# Total used tokens: 122  for card index  218
# Total used tokens: 203  for card index  219
# Card index:  220
# global_tokens_used_for_card_reading:  39664
# Total used tokens: 230  for card index  220
# Total used tokens: 134  for card index  221
# Total used tokens: 256  for card index  222
# Total used tokens: 204  for card index  223
# Total used tokens: 144  for card index  224
# Total used tokens: 166  for card index  225
# Total used tokens: 141  for card index  226
# Total used tokens: 140  for card index  227
# Total used tokens: 186  for card index  228
# Total used tokens: 169  for card index  229
# Total used tokens: 177  for card index  230
# Total used tokens: 311  for card index  231
# Total used tokens: 193  for card index  232
# Total used tokens: 215  for card index  233
# Total used tokens: 176  for card index  234
# Total used tokens: 155  for card index  235
# Total used tokens: 166  for card index  236
# Total used tokens: 152  for card index  237
# Total used tokens: 177  for card index  238
# Total used tokens: 130  for card index  239
# Card index:  240
# global_tokens_used_for_card_reading:  43286
# Total used tokens: 242  for card index  240
# Total used tokens: 155  for card index  241
# Total used tokens: 238  for card index  242
# Total used tokens: 125  for card index  243
# Total used tokens: 111  for card index  244
# Total used tokens: 173  for card index  245
# Total used tokens: 141  for card index  246
# Total used tokens: 130  for card index  247
# Total used tokens: 101  for card index  248
# Total used tokens: 207  for card index  249
# Total used tokens: 178  for card index  250
# Total used tokens: 236  for card index  251
# Total used tokens: 156  for card index  252
# Total used tokens: 101  for card index  253
# Total used tokens: 158  for card index  254
# Total used tokens: 190  for card index  255
# Total used tokens: 248  for card index  256
# Total used tokens: 220  for card index  257
# Total used tokens: 171  for card index  258
# Total used tokens: 164  for card index  259
# Card index:  260
# global_tokens_used_for_card_reading:  46731
# Total used tokens: 152  for card index  260
# Total used tokens: 116  for card index  261
# Total used tokens: 136  for card index  262
# Total used tokens: 268  for card index  263
# Total used tokens: 133  for card index  264
# Total used tokens: 172  for card index  265
# Total used tokens: 200  for card index  266
# Total used tokens: 164  for card index  267
# Total used tokens: 168  for card index  268
# Total used tokens: 172  for card index  269
# Total used tokens: 253  for card index  270
# Total used tokens: 191  for card index  271
# Total used tokens: 132  for card index  272
# Total used tokens: 177  for card index  273
# Total used tokens: 214  for card index  274
# Total used tokens: 177  for card index  275
# Total used tokens: 211  for card index  276
# Total used tokens: 313  for card index  277
# Total used tokens: 180  for card index  278
# Total used tokens: 139  for card index  279
# Card index:  280
# global_tokens_used_for_card_reading:  50399
# Total used tokens: 250  for card index  280
# Total used tokens: 238  for card index  281
# Total used tokens: 264  for card index  282
# Total used tokens: 178  for card index  283
# Total used tokens: 141  for card index  284
# Total used tokens: 193  for card index  285
# Total used tokens: 205  for card index  286
# Total used tokens: 153  for card index  287
# Total used tokens: 137  for card index  288
# Total used tokens: 137  for card index  289
# Total used tokens: 106  for card index  290
# Total used tokens: 142  for card index  291
# Total used tokens: 181  for card index  292
# Total used tokens: 212  for card index  293
# Total used tokens: 174  for card index  294
# Total used tokens: 212  for card index  295
# Total used tokens: 164  for card index  296
# Total used tokens: 185  for card index  297
# Total used tokens: 193  for card index  298
# Total used tokens: 193  for card index  299
# Card index:  300
# global_tokens_used_for_card_reading:  54057
# Total used tokens: 228  for card index  300
# Total used tokens: 205  for card index  301
# Total used tokens: 138  for card index  302
# Total used tokens: 181  for card index  303
# Total used tokens: 144  for card index  304
# Total used tokens: 167  for card index  305
# Total used tokens: 192  for card index  306
# Total used tokens: 158  for card index  307
# Total used tokens: 199  for card index  308
# Total used tokens: 230  for card index  309
# Total used tokens: 217  for card index  310
# Total used tokens: 153  for card index  311
# Total used tokens: 133  for card index  312
# Total used tokens: 249  for card index  313
# Total used tokens: 167  for card index  314
# Total used tokens: 147  for card index  315
# Total used tokens: 150  for card index  316
# Total used tokens: 173  for card index  317
# Total used tokens: 159  for card index  318
# Total used tokens: 145  for card index  319
# Card index:  320
# global_tokens_used_for_card_reading:  57592
# Total used tokens: 253  for card index  320
# Total used tokens: 196  for card index  321
# Total used tokens: 183  for card index  322
# Total used tokens: 241  for card index  323
# Total used tokens: 114  for card index  324
# Total used tokens: 316  for card index  325
# Total used tokens: 151  for card index  326
# Total used tokens: 266  for card index  327
# Total used tokens: 209  for card index  328
# Total used tokens: 182  for card index  329
# Total used tokens: 152  for card index  330
# Total used tokens: 217  for card index  331
# Total used tokens: 232  for card index  332
# Total used tokens: 197  for card index  333
# Total used tokens: 228  for card index  334
# Total used tokens: 183  for card index  335
# Total used tokens: 166  for card index  336
# Total used tokens: 271  for card index  337
# Total used tokens: 173  for card index  338
# Total used tokens: 102  for card index  339
# Card index:  340
# global_tokens_used_for_card_reading:  61624
# Total used tokens: 283  for card index  340
# Total used tokens: 224  for card index  341
# Total used tokens: 164  for card index  342
# Total used tokens: 192  for card index  343
# Total used tokens: 153  for card index  344
# Total used tokens: 122  for card index  345
# Total used tokens: 157  for card index  346
# Total used tokens: 138  for card index  347
# Total used tokens: 154  for card index  348
# Total used tokens: 202  for card index  349
# Total used tokens: 223  for card index  350
# Total used tokens: 154  for card index  351
# Total used tokens: 215  for card index  352
# Total used tokens: 122  for card index  353
# Total used tokens: 183  for card index  354
# Total used tokens: 193  for card index  355
# Total used tokens: 152  for card index  356
# Total used tokens: 202  for card index  357
# Total used tokens: 264  for card index  358
# Total used tokens: 173  for card index  359
# Card index:  360
# global_tokens_used_for_card_reading:  65294
# Total used tokens: 120  for card index  360
# Total used tokens: 166  for card index  361
# Total used tokens: 242  for card index  362
# Total used tokens: 135  for card index  363
# Total used tokens: 245  for card index  364
# Total used tokens: 203  for card index  365
# Total used tokens: 201  for card index  366
# Total used tokens: 146  for card index  367
# Total used tokens: 198  for card index  368
# Total used tokens: 215  for card index  369
# Total used tokens: 199  for card index  370
# Total used tokens: 204  for card index  371
# Total used tokens: 291  for card index  372
# Total used tokens: 265  for card index  373
# Total used tokens: 205  for card index  374
# Total used tokens: 137  for card index  375
# Total used tokens: 160  for card index  376
# Total used tokens: 115  for card index  377
# Total used tokens: 119  for card index  378
# Total used tokens: 171  for card index  379
# Card index:  380
# global_tokens_used_for_card_reading:  69031
# Total used tokens: 154  for card index  380
# Total used tokens: 139  for card index  381
# Total used tokens: 148  for card index  382
# Total used tokens: 254  for card index  383
# Total used tokens: 167  for card index  384
# Total used tokens: 164  for card index  385
# Total used tokens: 207  for card index  386
# Total used tokens: 155  for card index  387
# Total used tokens: 151  for card index  388
# Total used tokens: 201  for card index  389
# Total used tokens: 145  for card index  390
# Total used tokens: 126  for card index  391
# Total used tokens: 263  for card index  392
# Total used tokens: 144  for card index  393
# Total used tokens: 137  for card index  394
# Total used tokens: 146  for card index  395
# Total used tokens: 112  for card index  396
# Total used tokens: 131  for card index  397
# Total used tokens: 146  for card index  398
# Total used tokens: 213  for card index  399
# Card index:  400
# global_tokens_used_for_card_reading:  72334
# Total used tokens: 227  for card index  400
# Total used tokens: 272  for card index  401
# Total used tokens: 148  for card index  402
# Total used tokens: 310  for card index  403
# Total used tokens: 187  for card index  404
# Total used tokens: 115  for card index  405
# Total used tokens: 155  for card index  406
# Total used tokens: 158  for card index  407
# Total used tokens: 172  for card index  408
# Total used tokens: 170  for card index  409
# Total used tokens: 181  for card index  410
# Total used tokens: 161  for card index  411
# Total used tokens: 120  for card index  412
# Total used tokens: 120  for card index  413
# Total used tokens: 160  for card index  414
# Total used tokens: 215  for card index  415
# Total used tokens: 156  for card index  416
# Total used tokens: 171  for card index  417
# Total used tokens: 105  for card index  418
# Total used tokens: 246  for card index  419
# Card index:  420
# global_tokens_used_for_card_reading:  75883
# Total used tokens: 223  for card index  420
# Total used tokens: 145  for card index  421
# Total used tokens: 153  for card index  422
# Total used tokens: 206  for card index  423
# Total used tokens: 225  for card index  424
# Total used tokens: 198  for card index  425
# Total used tokens: 275  for card index  426
# Total used tokens: 166  for card index  427
# Total used tokens: 141  for card index  428
# Total used tokens: 194  for card index  429
# Total used tokens: 191  for card index  430
# Total used tokens: 194  for card index  431
# Total used tokens: 161  for card index  432
# Total used tokens: 243  for card index  433
# Total used tokens: 182  for card index  434
# Total used tokens: 187  for card index  435
# Total used tokens: 232  for card index  436
# Total used tokens: 168  for card index  437
# Total used tokens: 246  for card index  438
# Total used tokens: 221  for card index  439
# Card index:  440
# global_tokens_used_for_card_reading:  79834
# Total used tokens: 173  for card index  440
# Total used tokens: 167  for card index  441
# Total used tokens: 189  for card index  442
# Total used tokens: 166  for card index  443
# Total used tokens: 158  for card index  444
# Total used tokens: 234  for card index  445
# Total used tokens: 205  for card index  446
# Total used tokens: 192  for card index  447
# Total used tokens: 172  for card index  448
# Total used tokens: 175  for card index  449
# Total used tokens: 165  for card index  450
# Total used tokens: 155  for card index  451
# Total used tokens: 175  for card index  452
# Total used tokens: 200  for card index  453
# Total used tokens: 172  for card index  454
# Total used tokens: 193  for card index  455
# Total used tokens: 191  for card index  456
# Total used tokens: 194  for card index  457
# Total used tokens: 223  for card index  458
# Total used tokens: 135  for card index  459
# Card index:  460
# global_tokens_used_for_card_reading:  83468
# Total used tokens: 226  for card index  460
# Total used tokens: 188  for card index  461
# Total used tokens: 160  for card index  462
# Total used tokens: 103  for card index  463
# Total used tokens: 242  for card index  464
# Total used tokens: 156  for card index  465
# Total used tokens: 194  for card index  466
# Total used tokens: 127  for card index  467
# Total used tokens: 181  for card index  468
# Total used tokens: 168  for card index  469
# Total used tokens: 189  for card index  470
# Total used tokens: 180  for card index  471
# Total used tokens: 132  for card index  472
# Total used tokens: 131  for card index  473
# Total used tokens: 269  for card index  474
# Total used tokens: 230  for card index  475
# Total used tokens: 357  for card index  476
# Total used tokens: 273  for card index  477
# Total used tokens: 159  for card index  478
# Total used tokens: 302  for card index  479
# Card index:  480
# global_tokens_used_for_card_reading:  87435
# Total used tokens: 142  for card index  480
# Total used tokens: 163  for card index  481
# Total used tokens: 148  for card index  482
# Total used tokens: 218  for card index  483
# Total used tokens: 206  for card index  484
# Total used tokens: 184  for card index  485
# Total used tokens: 172  for card index  486
# Total used tokens: 192  for card index  487
# Total used tokens: 147  for card index  488
# Total used tokens: 186  for card index  489
# Total used tokens: 227  for card index  490
# Total used tokens: 179  for card index  491
# Total used tokens: 155  for card index  492
# Total used tokens: 213  for card index  493
# Total used tokens: 296  for card index  494
# Total used tokens: 139  for card index  495
# Total used tokens: 203  for card index  496
# Total used tokens: 206  for card index  497
# Total used tokens: 116  for card index  498
# Total used tokens: 208  for card index  499
# Card index:  500
# global_tokens_used_for_card_reading:  91135
# Total used tokens: 197  for card index  500
# Total used tokens: 157  for card index  501
# Total used tokens: 173  for card index  502
# Total used tokens: 284  for card index  503
# Total used tokens: 257  for card index  504
# Total used tokens: 228  for card index  505
# Total used tokens: 227  for card index  506
# Total used tokens: 216  for card index  507
# Total used tokens: 159  for card index  508
# Total used tokens: 174  for card index  509
# Total used tokens: 212  for card index  510
# Total used tokens: 207  for card index  511
# Total used tokens: 123  for card index  512
# Total used tokens: 210  for card index  513
# Total used tokens: 117  for card index  514
# Total used tokens: 158  for card index  515
# Total used tokens: 265  for card index  516
# Total used tokens: 201  for card index  517
# Total used tokens: 114  for card index  518
# Total used tokens: 188  for card index  519
# Card index:  520
# global_tokens_used_for_card_reading:  95002
# Total used tokens: 256  for card index  520
# Total used tokens: 177  for card index  521
# Total used tokens: 234  for card index  522
# Total used tokens: 109  for card index  523
# Total used tokens: 129  for card index  524
# Total used tokens: 197  for card index  525
# Total used tokens: 167  for card index  526
# Total used tokens: 176  for card index  527
# Total used tokens: 168  for card index  528
# Total used tokens: 193  for card index  529
# Total used tokens: 148  for card index  530
# Total used tokens: 210  for card index  531
# Total used tokens: 209  for card index  532
# Total used tokens: 140  for card index  533
# Total used tokens: 133  for card index  534
# Total used tokens: 166  for card index  535
# Total used tokens: 181  for card index  536
# Total used tokens: 190  for card index  537
# Total used tokens: 207  for card index  538
# Total used tokens: 229  for card index  539
# Card index:  0
# global_tokens_used_for_card_reading:  0
# Total used tokens: 90  for card index  0
# Total used tokens: 101  for card index  1
# Total used tokens: 96  for card index  2
# Total used tokens: 89  for card index  3
# Total used tokens: 139  for card index  4
# Total used tokens: 118  for card index  5
# Total used tokens: 145  for card index  6
# Total used tokens: 121  for card index  7
# Total used tokens: 119  for card index  8
# Total used tokens: 107  for card index  9
# Total used tokens: 103  for card index  10
# Total used tokens: 93  for card index  11
# Total used tokens: 169  for card index  12
# Total used tokens: 120  for card index  13
# Total used tokens: 107  for card index  14
# Total used tokens: 119  for card index  15
# Total used tokens: 116  for card index  16
# Total used tokens: 97  for card index  17
# Total used tokens: 103  for card index  18
# Total used tokens: 97  for card index  19
# Card index:  20
# global_tokens_used_for_card_reading:  2249
# Total used tokens: 133  for card index  20
# Total used tokens: 119  for card index  21
# Total used tokens: 124  for card index  22
# Total used tokens: 96  for card index  23
# Total used tokens: 125  for card index  24
# Total used tokens: 149  for card index  25
# Total used tokens: 165  for card index  26
# Total used tokens: 174  for card index  27
# Total used tokens: 126  for card index  28
# Total used tokens: 140  for card index  29
# Total used tokens: 101  for card index  30
# Total used tokens: 114  for card index  31
# Total used tokens: 93  for card index  32
# Total used tokens: 91  for card index  33
# Total used tokens: 105  for card index  34
# Total used tokens: 112  for card index  35
# Total used tokens: 97  for card index  36
# Total used tokens: 105  for card index  37
# Total used tokens: 106  for card index  38
# Total used tokens: 89  for card index  39
# Card index:  40
# global_tokens_used_for_card_reading:  4613
# Total used tokens: 113  for card index  40
# Total used tokens: 118  for card index  41
# Total used tokens: 129  for card index  42
# Total used tokens: 120  for card index  43
# Total used tokens: 118  for card index  44
# Total used tokens: 104  for card index  45
# Total used tokens: 206  for card index  46
# Total used tokens: 129  for card index  47
# Total used tokens: 117  for card index  48
# Total used tokens: 100  for card index  49
# Total used tokens: 89  for card index  50
# Total used tokens: 122  for card index  51
# Total used tokens: 147  for card index  52
# Total used tokens: 122  for card index  53
# Total used tokens: 110  for card index  54
# Total used tokens: 94  for card index  55
# Total used tokens: 97  for card index  56
# Total used tokens: 93  for card index  57
# Total used tokens: 103  for card index  58
# Total used tokens: 104  for card index  59
# Card index:  60
# global_tokens_used_for_card_reading:  6948
# Total used tokens: 98  for card index  60
# Total used tokens: 106  for card index  61
# Total used tokens: 99  for card index  62
# Total used tokens: 108  for card index  63
# Total used tokens: 119  for card index  64
# Total used tokens: 113  for card index  65
# Total used tokens: 168  for card index  66
# Total used tokens: 138  for card index  67
# Total used tokens: 138  for card index  68
# Total used tokens: 122  for card index  69
# Total used tokens: 179  for card index  70
# Total used tokens: 100  for card index  71
# Total used tokens: 104  for card index  72
# Total used tokens: 105  for card index  73
# Total used tokens: 144  for card index  74
# Total used tokens: 118  for card index  75
# Total used tokens: 114  for card index  76
# Total used tokens: 137  for card index  77
# Total used tokens: 106  for card index  78
# Total used tokens: 115  for card index  79
# Card index:  80
# global_tokens_used_for_card_reading:  9379
# Total used tokens: 105  for card index  80
# Total used tokens: 135  for card index  81
# Total used tokens: 121  for card index  82
# Total used tokens: 117  for card index  83
# Total used tokens: 82  for card index  84
# Total used tokens: 110  for card index  85
# Total used tokens: 147  for card index  86
# Total used tokens: 150  for card index  87
# Total used tokens: 124  for card index  88
# Total used tokens: 95  for card index  89
# Total used tokens: 91  for card index  90
# Total used tokens: 119  for card index  91
# Total used tokens: 132  for card index  92
# Total used tokens: 97  for card index  93
# Total used tokens: 134  for card index  94
# Total used tokens: 121  for card index  95
# Total used tokens: 124  for card index  96
# Total used tokens: 102  for card index  97
# Total used tokens: 102  for card index  98
# Total used tokens: 107  for card index  99
# Card index:  100
# global_tokens_used_for_card_reading:  11694
# Total used tokens: 99  for card index  100
# Total used tokens: 151  for card index  101
# Total used tokens: 148  for card index  102
# Total used tokens: 121  for card index  103
# Total used tokens: 90  for card index  104
# Total used tokens: 116  for card index  105
# Total used tokens: 86  for card index  106
# Total used tokens: 97  for card index  107
# Total used tokens: 111  for card index  108
# Total used tokens: 138  for card index  109
# Total used tokens: 152  for card index  110
# Total used tokens: 107  for card index  111
# Total used tokens: 107  for card index  112
# Total used tokens: 143  for card index  113
# Total used tokens: 91  for card index  114
# Total used tokens: 144  for card index  115
# Total used tokens: 105  for card index  116
# Total used tokens: 111  for card index  117
# Total used tokens: 115  for card index  118
# Total used tokens: 100  for card index  119
# Card index:  120
# global_tokens_used_for_card_reading:  14026
# Total used tokens: 113  for card index  120
# Total used tokens: 117  for card index  121
# Total used tokens: 99  for card index  122
# Total used tokens: 96  for card index  123
# Total used tokens: 109  for card index  124
# Total used tokens: 95  for card index  125
# Total used tokens: 185  for card index  126
# Total used tokens: 173  for card index  127
# Total used tokens: 144  for card index  128
# Total used tokens: 124  for card index  129
# Total used tokens: 97  for card index  130
# Total used tokens: 121  for card index  131
# Total used tokens: 119  for card index  132
# Total used tokens: 114  for card index  133
# Total used tokens: 94  for card index  134
# Total used tokens: 134  for card index  135
# Total used tokens: 243  for card index  136
# Total used tokens: 140  for card index  137
# Total used tokens: 105  for card index  138
# Total used tokens: 98  for card index  139
# Card index:  140
# global_tokens_used_for_card_reading:  16546
# Total used tokens: 96  for card index  140
# Total used tokens: 109  for card index  141
# Total used tokens: 106  for card index  142
# Total used tokens: 118  for card index  143
# Total used tokens: 150  for card index  144
# Total used tokens: 102  for card index  145
# Total used tokens: 105  for card index  146
# Total used tokens: 100  for card index  147
# Total used tokens: 114  for card index  148
# Total used tokens: 112  for card index  149
# Total used tokens: 116  for card index  150
# Total used tokens: 91  for card index  151
# Total used tokens: 126  for card index  152
# Total used tokens: 119  for card index  153
# Total used tokens: 104  for card index  154
# Total used tokens: 137  for card index  155
# Total used tokens: 95  for card index  156
# Total used tokens: 128  for card index  157
# Total used tokens: 104  for card index  158
# Total used tokens: 102  for card index  159
# Card index:  160
# global_tokens_used_for_card_reading:  18780
# Total used tokens: 93  for card index  160
# Total used tokens: 117  for card index  161
# Total used tokens: 123  for card index  162
# Total used tokens: 117  for card index  163
# Total used tokens: 108  for card index  164
# Total used tokens: 113  for card index  165
# Total used tokens: 112  for card index  166
# Total used tokens: 134  for card index  167
# Total used tokens: 139  for card index  168
# Total used tokens: 128  for card index  169
# Total used tokens: 124  for card index  170
# Total used tokens: 143  for card index  171
# Total used tokens: 122  for card index  172
# Total used tokens: 107  for card index  173
# Total used tokens: 99  for card index  174
# Total used tokens: 102  for card index  175
# Total used tokens: 112  for card index  176
# Total used tokens: 114  for card index  177
# Total used tokens: 118  for card index  178
# Total used tokens: 103  for card index  179
# Card index:  180
# global_tokens_used_for_card_reading:  21108
# Total used tokens: 143  for card index  180
# Total used tokens: 202  for card index  181
# Total used tokens: 133  for card index  182
# Total used tokens: 136  for card index  183
# Total used tokens: 90  for card index  184
# Total used tokens: 133  for card index  185
# Total used tokens: 118  for card index  186
# Total used tokens: 118  for card index  187
# Total used tokens: 102  for card index  188
# Total used tokens: 121  for card index  189
# Total used tokens: 99  for card index  190
# Total used tokens: 90  for card index  191
# Total used tokens: 95  for card index  192
# Total used tokens: 121  for card index  193
# Total used tokens: 106  for card index  194
# Total used tokens: 100  for card index  195
# Total used tokens: 99  for card index  196
# Total used tokens: 87  for card index  197
# Total used tokens: 102  for card index  198
# Total used tokens: 102  for card index  199
# Card index:  200
# global_tokens_used_for_card_reading:  23405
# Total used tokens: 112  for card index  200
# Total used tokens: 99  for card index  201
# Total used tokens: 95  for card index  202
# Total used tokens: 91  for card index  203
# Total used tokens: 111  for card index  204
# Total used tokens: 124  for card index  205
# Total used tokens: 75  for card index  206
# Total used tokens: 118  for card index  207
# Total used tokens: 92  for card index  208
# Total used tokens: 108  for card index  209
# Total used tokens: 113  for card index  210
# Total used tokens: 139  for card index  211
# Total used tokens: 227  for card index  212
# Total used tokens: 86  for card index  213
# Total used tokens: 91  for card index  214
# Total used tokens: 106  for card index  215
# Total used tokens: 151  for card index  216
# Total used tokens: 114  for card index  217
# Total used tokens: 98  for card index  218
# Total used tokens: 148  for card index  219
# Card index:  220
# global_tokens_used_for_card_reading:  25703
# Total used tokens: 117  for card index  220
# Total used tokens: 88  for card index  221
# Total used tokens: 198  for card index  222
# Total used tokens: 106  for card index  223
# Total used tokens: 97  for card index  224
# Total used tokens: 112  for card index  225
# Total used tokens: 98  for card index  226
# Total used tokens: 119  for card index  227
# Total used tokens: 116  for card index  228
# Total used tokens: 110  for card index  229
# Total used tokens: 102  for card index  230
# Total used tokens: 151  for card index  231
# Total used tokens: 104  for card index  232
# Total used tokens: 141  for card index  233
# Total used tokens: 123  for card index  234
# Total used tokens: 99  for card index  235
# Total used tokens: 97  for card index  236
# Total used tokens: 108  for card index  237
# Total used tokens: 106  for card index  238
# Total used tokens: 109  for card index  239
# Card index:  240
# global_tokens_used_for_card_reading:  28004
# Total used tokens: 118  for card index  240
# Total used tokens: 116  for card index  241
# Total used tokens: 117  for card index  242
# Total used tokens: 109  for card index  243
# Total used tokens: 95  for card index  244
# Total used tokens: 133  for card index  245
# Total used tokens: 121  for card index  246
# Total used tokens: 96  for card index  247
# Total used tokens: 81  for card index  248
# Total used tokens: 125  for card index  249
# Total used tokens: 124  for card index  250
# Total used tokens: 154  for card index  251
# Total used tokens: 133  for card index  252
# Total used tokens: 88  for card index  253
# Total used tokens: 88  for card index  254
# Total used tokens: 110  for card index  255
# Total used tokens: 87  for card index  256
# Total used tokens: 129  for card index  257
# Total used tokens: 125  for card index  258
# Total used tokens: 141  for card index  259
# Card index:  260
# global_tokens_used_for_card_reading:  30294
# Total used tokens: 113  for card index  260
# Total used tokens: 116  for card index  261
# Total used tokens: 134  for card index  262
# Total used tokens: 122  for card index  263
# Total used tokens: 106  for card index  264
# Total used tokens: 131  for card index  265
# Total used tokens: 120  for card index  266
# Total used tokens: 113  for card index  267
# Total used tokens: 131  for card index  268
# Total used tokens: 116  for card index  269
# Total used tokens: 111  for card index  270
# Total used tokens: 125  for card index  271
# Total used tokens: 115  for card index  272
# Total used tokens: 125  for card index  273
# Total used tokens: 132  for card index  274
# Total used tokens: 88  for card index  275
# Total used tokens: 121  for card index  276
# Total used tokens: 148  for card index  277
# Total used tokens: 94  for card index  278
# Total used tokens: 85  for card index  279
# Card index:  280
# global_tokens_used_for_card_reading:  32640
# Total used tokens: 170  for card index  280
# Total used tokens: 145  for card index  281
# Total used tokens: 147  for card index  282
# Total used tokens: 131  for card index  283
# Total used tokens: 125  for card index  284
# Total used tokens: 153  for card index  285
# Total used tokens: 121  for card index  286
# Total used tokens: 97  for card index  287
# Total used tokens: 121  for card index  288
# Total used tokens: 112  for card index  289
# Total used tokens: 100  for card index  290
# Total used tokens: 118  for card index  291
# Total used tokens: 122  for card index  292
# Total used tokens: 160  for card index  293
# Total used tokens: 154  for card index  294
# Total used tokens: 123  for card index  295
# Total used tokens: 125  for card index  296
# Total used tokens: 102  for card index  297
# Total used tokens: 106  for card index  298
# Total used tokens: 145  for card index  299
# Card index:  300
# global_tokens_used_for_card_reading:  35217
# Total used tokens: 127  for card index  300
# Total used tokens: 135  for card index  301
# Total used tokens: 109  for card index  302
# Total used tokens: 110  for card index  303
# Total used tokens: 88  for card index  304
# Total used tokens: 133  for card index  305
# Total used tokens: 121  for card index  306
# Total used tokens: 83  for card index  307
# Total used tokens: 117  for card index  308
# Total used tokens: 115  for card index  309
# Total used tokens: 122  for card index  310
# Total used tokens: 123  for card index  311
# Total used tokens: 115  for card index  312
# Total used tokens: 97  for card index  313
# Total used tokens: 110  for card index  314
# Total used tokens: 95  for card index  315
# Total used tokens: 113  for card index  316
# Total used tokens: 101  for card index  317
# Total used tokens: 117  for card index  318
# Total used tokens: 89  for card index  319
# Card index:  320
# global_tokens_used_for_card_reading:  37437
# Total used tokens: 137  for card index  320
# Total used tokens: 121  for card index  321
# Total used tokens: 111  for card index  322
# Total used tokens: 123  for card index  323
# Total used tokens: 85  for card index  324
# Total used tokens: 128  for card index  325
# Total used tokens: 101  for card index  326
# Total used tokens: 228  for card index  327
# Total used tokens: 106  for card index  328
# Total used tokens: 101  for card index  329
# Total used tokens: 111  for card index  330
# Total used tokens: 142  for card index  331
# Total used tokens: 98  for card index  332
# Total used tokens: 107  for card index  333
# Total used tokens: 157  for card index  334
# Total used tokens: 113  for card index  335
# Total used tokens: 141  for card index  336
# Total used tokens: 146  for card index  337
# Total used tokens: 129  for card index  338
# Total used tokens: 107  for card index  339
# Card index:  340
# global_tokens_used_for_card_reading:  39929
# Total used tokens: 135  for card index  340
# Total used tokens: 174  for card index  341
# Total used tokens: 149  for card index  342
# Total used tokens: 141  for card index  343
# Total used tokens: 132  for card index  344
# Total used tokens: 108  for card index  345
# Total used tokens: 127  for card index  346
# Total used tokens: 113  for card index  347
# Total used tokens: 124  for card index  348
# Total used tokens: 133  for card index  349
# Total used tokens: 126  for card index  350
# Total used tokens: 104  for card index  351
# Total used tokens: 122  for card index  352
# Total used tokens: 94  for card index  353
# Total used tokens: 144  for card index  354
# Total used tokens: 123  for card index  355
# Total used tokens: 105  for card index  356
# Total used tokens: 120  for card index  357
# Total used tokens: 113  for card index  358
# Total used tokens: 108  for card index  359
# Card index:  360
# global_tokens_used_for_card_reading:  42424
# Total used tokens: 83  for card index  360
# Total used tokens: 102  for card index  361
# Total used tokens: 97  for card index  362
# Total used tokens: 93  for card index  363
# Total used tokens: 118  for card index  364
# Total used tokens: 107  for card index  365
# Total used tokens: 98  for card index  366
# Total used tokens: 112  for card index  367
# Total used tokens: 100  for card index  368
# Total used tokens: 125  for card index  369
# Total used tokens: 144  for card index  370
# Total used tokens: 119  for card index  371
# Total used tokens: 171  for card index  372
# Total used tokens: 139  for card index  373
# Total used tokens: 134  for card index  374
# Total used tokens: 113  for card index  375
# Total used tokens: 121  for card index  376
# Total used tokens: 118  for card index  377
# Total used tokens: 115  for card index  378
# Total used tokens: 118  for card index  379
# Card index:  380
# global_tokens_used_for_card_reading:  44751
# Total used tokens: 138  for card index  380
# Total used tokens: 116  for card index  381
# Total used tokens: 129  for card index  382
# Total used tokens: 179  for card index  383
# Total used tokens: 120  for card index  384
# Total used tokens: 118  for card index  385
# Total used tokens: 108  for card index  386
# Total used tokens: 115  for card index  387
# Total used tokens: 121  for card index  388
# Total used tokens: 116  for card index  389
# Total used tokens: 90  for card index  390
# Total used tokens: 108  for card index  391
# Total used tokens: 169  for card index  392
# Total used tokens: 97  for card index  393
# Total used tokens: 119  for card index  394
# Total used tokens: 100  for card index  395
# Total used tokens: 110  for card index  396
# Total used tokens: 112  for card index  397
# Total used tokens: 100  for card index  398
# Total used tokens: 133  for card index  399
# Card index:  400
# global_tokens_used_for_card_reading:  47149
# Total used tokens: 121  for card index  400
# Total used tokens: 118  for card index  401
# Total used tokens: 106  for card index  402
# Total used tokens: 123  for card index  403
# Total used tokens: 129  for card index  404
# Total used tokens: 85  for card index  405
# Total used tokens: 128  for card index  406
# Total used tokens: 97  for card index  407
# Total used tokens: 134  for card index  408
# Total used tokens: 119  for card index  409
# Total used tokens: 104  for card index  410
# Total used tokens: 107  for card index  411
# Total used tokens: 98  for card index  412
# Total used tokens: 102  for card index  413
# Total used tokens: 140  for card index  414
# Total used tokens: 121  for card index  415
# Total used tokens: 128  for card index  416
# Total used tokens: 114  for card index  417
# Total used tokens: 89  for card index  418
# Total used tokens: 154  for card index  419
# Card index:  420
# global_tokens_used_for_card_reading:  49466
# Total used tokens: 139  for card index  420
# Total used tokens: 102  for card index  421
# Total used tokens: 139  for card index  422
# Total used tokens: 111  for card index  423
# Total used tokens: 135  for card index  424
# Total used tokens: 119  for card index  425
# Total used tokens: 124  for card index  426
# Total used tokens: 92  for card index  427
# Total used tokens: 112  for card index  428
# Total used tokens: 100  for card index  429
# Total used tokens: 105  for card index  430
# Total used tokens: 87  for card index  431
# Total used tokens: 100  for card index  432
# Total used tokens: 108  for card index  433
# Total used tokens: 116  for card index  434
# Total used tokens: 110  for card index  435
# Total used tokens: 145  for card index  436
# Total used tokens: 112  for card index  437
# Total used tokens: 128  for card index  438
# Total used tokens: 120  for card index  439
# Card index:  440
# global_tokens_used_for_card_reading:  51770
# Total used tokens: 95  for card index  440
# Total used tokens: 105  for card index  441
# Total used tokens: 101  for card index  442
# Total used tokens: 129  for card index  443
# Total used tokens: 98  for card index  444
# Total used tokens: 126  for card index  445
# Total used tokens: 125  for card index  446
# Total used tokens: 101  for card index  447
# Total used tokens: 93  for card index  448
# Total used tokens: 100  for card index  449
# Total used tokens: 128  for card index  450
# Total used tokens: 86  for card index  451
# Total used tokens: 119  for card index  452
# Total used tokens: 132  for card index  453
# Total used tokens: 99  for card index  454
# Total used tokens: 122  for card index  455
# Total used tokens: 115  for card index  456
# Total used tokens: 108  for card index  457
# Total used tokens: 160  for card index  458
# Total used tokens: 99  for card index  459
# Card index:  460
# global_tokens_used_for_card_reading:  54011
# Total used tokens: 145  for card index  460
# Total used tokens: 136  for card index  461
# Total used tokens: 96  for card index  462
# Total used tokens: 89  for card index  463
# Total used tokens: 97  for card index  464
# Total used tokens: 104  for card index  465
# Total used tokens: 98  for card index  466
# Total used tokens: 94  for card index  467
# Total used tokens: 94  for card index  468
# Total used tokens: 104  for card index  469
# Total used tokens: 101  for card index  470
# Total used tokens: 83  for card index  471
# Total used tokens: 102  for card index  472
# Total used tokens: 93  for card index  473
# Total used tokens: 152  for card index  474
# Total used tokens: 136  for card index  475
# Total used tokens: 180  for card index  476
# Total used tokens: 139  for card index  477
# Total used tokens: 110  for card index  478
# Total used tokens: 148  for card index  479
# Card index:  480
# global_tokens_used_for_card_reading:  56312
# Total used tokens: 107  for card index  480
# Total used tokens: 95  for card index  481
# Total used tokens: 97  for card index  482
# Total used tokens: 107  for card index  483
# Total used tokens: 116  for card index  484
# Total used tokens: 122  for card index  485
# Total used tokens: 92  for card index  486
# Total used tokens: 109  for card index  487
# Total used tokens: 112  for card index  488
# Total used tokens: 150  for card index  489
# Total used tokens: 122  for card index  490
# Total used tokens: 145  for card index  491
# Total used tokens: 95  for card index  492
# Total used tokens: 182  for card index  493
# Total used tokens: 213  for card index  494
# Total used tokens: 113  for card index  495
# Total used tokens: 139  for card index  496
# Total used tokens: 152  for card index  497
# Total used tokens: 85  for card index  498
# Total used tokens: 137  for card index  499
# Card index:  500
# global_tokens_used_for_card_reading:  58802
# Total used tokens: 119  for card index  500
# Total used tokens: 83  for card index  501
# Total used tokens: 114  for card index  502
# Total used tokens: 119  for card index  503
# Total used tokens: 128  for card index  504
# Total used tokens: 133  for card index  505
# Total used tokens: 205  for card index  506
# Total used tokens: 109  for card index  507
# Total used tokens: 114  for card index  508
# Total used tokens: 122  for card index  509
# Total used tokens: 117  for card index  510
# Total used tokens: 144  for card index  511
# Total used tokens: 100  for card index  512
# Total used tokens: 163  for card index  513
# Total used tokens: 106  for card index  514
# Total used tokens: 92  for card index  515
# Total used tokens: 125  for card index  516
# Total used tokens: 127  for card index  517
# Total used tokens: 117  for card index  518
# Total used tokens: 97  for card index  519
# Card index:  520
# global_tokens_used_for_card_reading:  61236
# Total used tokens: 108  for card index  520
# Total used tokens: 165  for card index  521
# Total used tokens: 122  for card index  522
# Total used tokens: 108  for card index  523
# Total used tokens: 88  for card index  524
# Total used tokens: 117  for card index  525
# Total used tokens: 113  for card index  526
# Total used tokens: 124  for card index  527
# Total used tokens: 86  for card index  528
# Total used tokens: 119  for card index  529
# Total used tokens: 107  for card index  530
# Total used tokens: 154  for card index  531
# Total used tokens: 138  for card index  532
# Total used tokens: 118  for card index  533
# Total used tokens: 104  for card index  534
# Total used tokens: 127  for card index  535
# Total used tokens: 137  for card index  536
# Total used tokens: 112  for card index  537
# Total used tokens: 147  for card index  538
# Total used tokens: 137  for card index  539

# %% [markdown]
# ## Build a knowledge graph

# %%
# Reload basic cards to start to make knowledge graph 
cards_df_abstraction_groups = read_cards_df_from_json('my_flash_cards_general_cards_df_abstraction_groups')

# # For loading multiple json files
# cards_df_abstraction_groups_lab = read_cards_df_from_json('my_flash_cards_lab_cards_df_abstraction_groups')
# cards_df_abstraction_groups = pd.concat([cards_df_abstraction_groups_general, 
#                                          cards_df_abstraction_groups_lab], 
#                                         ignore_index=True)

print("Cards loaded:", len(cards_df_abstraction_groups))
# Out:
# Cards loaded: 540

# %%
# Build a graph from real flashcard data 
kGraph = KnowledgeGraph(lower_bound_epsilon=0.05)

# %%
# Add card deck to kGraph
card_deck = create_card_deck_from_dataframe_of_abstraction_groups(cards_df_abstraction_groups)
title_list = kGraph.add_card_deck(card_deck, verbose=True)
kGraph.update_all_embeddings(verbose=True)
# Out:
# Adding 540 cards
# Recalculating relative abstraction
#    Node number:  0 , Title: "Simplifying Input Arguments" at time  0.0
#    Node number:  200 , Title: "MADE" at time  0.75
#    Node number:  400 , Title: "Doc String" at time  1.62
#    Node number:  600 , Title: "Legal Framework" at time  2.93
#    Node number:  800 , Title: "Or" at time  3.8
#    Node number:  1000 , Title: "Average" at time  4.48
#    Node number:  1200 , Title: "Dynamic" at time  5.54
#    Node number:  1400 , Title: "Metals Material Engineering" at time  6.35
#    Node number:  1600 , Title: "Nlp" at time  8.13
#    Node number:  1800 , Title: "Data Type" at time  8.99
#    Node number:  2000 , Title: "Northern Reef" at time  9.83
#    Node number:  2200 , Title: "Conservation" at time  10.62
#    Node number:  2400 , Title: "Local Interaction" at time  11.64
#    Node number:  2600 , Title: "Sustainable" at time  13.29
#    Node number:  2800 , Title: "View" at time  14.1
# Updating raw embedding vectors
#    Node number:  0 , Title: "Simplifying Input Arguments" at time  0.0
#    Node number:  200 , Title: "MADE" at time  3.42
#    Node number:  400 , Title: "Doc String" at time  4.84
#    Node number:  600 , Title: "Legal Framework" at time  6.81
#    Node number:  800 , Title: "Or" at time  8.29
#    Node number:  1000 , Title: "Average" at time  9.5
#    Node number:  1200 , Title: "Dynamic" at time  11.14
#    Node number:  1400 , Title: "Metals Material Engineering" at time  12.54
#    Node number:  1600 , Title: "Nlp" at time  15.03
#    Node number:  1800 , Title: "Data Type" at time  16.48
#    Node number:  2000 , Title: "Northern Reef" at time  17.9
#    Node number:  2200 , Title: "Conservation" at time  19.28
#    Node number:  2400 , Title: "Local Interaction" at time  20.78
#    Node number:  2600 , Title: "Sustainable" at time  22.95
#    Node number:  2800 , Title: "View" at time  24.41
# Updating all node embeddings:
#    Node number:  0 , Title: "Science" at time  0.0
#    Node number:  200 , Title: "Legal System" at time  18.82
#    Node number:  400 , Title: "Landfill" at time  23.05
#    Node number:  600 , Title: "Superposition Detection" at time  24.02
#    Node number:  800 , Title: "Loss Function" at time  26.07
#    Node number:  1000 , Title: "User Experience" at time  27.64
#    Node number:  1200 , Title: "Q(z)" at time  29.42
#    Node number:  1400 , Title: "Moving" at time  30.58
#    Node number:  1600 , Title: "1 - X" at time  31.64
#    Node number:  1800 , Title: "Multi-Layer Attention" at time  32.52
#    Node number:  2000 , Title: "Bond" at time  33.44
#    Node number:  2200 , Title: "Inner Product" at time  34.41
#    Node number:  2400 , Title: "Challenge" at time  35.99
#    Node number:  2600 , Title: "Pipeline Compressor" at time  37.68
#    Node number:  2800 , Title: "Increasing Dominance" at time  39.32

# %% [markdown]
# ## Query knowledge graph

# %% [markdown]
# ##### Question examples

# %%
################## Example questions ##################

# Actual flashcards, or very close. It seems to usually solve these.
# "What is the most basic model of how natural environments determine major animal types in a given biome?"
# "What are good practices for a function input and output when coding?"
# "What are two major problems with existing LLMs like ChatGPT?"
# "In the stratego paper, what is the regularized nash dynamics algorithm most similar to in other reinforcement learning algorithms?"

# Hard
# "If I am trying to fit a function, and it isn't very accurate, what method can I use to improve accuracy?"

# Easier
# "Why is boosting useful?"
# "Why do language models sometimes give wildly wrong answers when predicting text?"
# "What is the best way to learn new information about a new field of science?"
# "Why should I care about determinants?"
# "What happens in the drug approval process?"
# "What major event happened in Texas in 2021?"
# "How can I find the minimum of a function with a computer program?"
# "What probability distribution deals with repeated draws from a set with replacement?"
# "How hard is it to calculate the determinant of a matrix?"
# "What are ways to impove the scientific funding process?"
# "What is a multimodal neuron in a neural network?"
# "What will the probability distribution be if I count how many times something with a fixed rate happens over some period of time?"
# "When did the modern plants come into existence in evolutionary history?"
# "What is gradient descent?"
# "What is the sticky engine of growth for a startup?"
# "What is Jim Allison famous for?"
# "What modern encryption system works pretty well?"
# "How can I sort a list in python?"
# "How does a 3D metals printer work?"

# Not in distribution
# "When did the modern coral come into existence in evolutionary history?" # testing a case that wasn't present 
# "What causes the band structure of atoms in a periodic lattice to be sinusoidal?"
# "What remains to be determined about the structure of fermion pairs in the spin-imbalanced Hubbard model?"

# Fake information
# "A fleegdorf is stuck in my garage, what do I do?"

# %% [markdown]
# ##### Exploring

# %%
flashcardQuestion = "How hard is it to calculate the determinant of a matrix?"
num_cards_to_show = 10
verbose = True
extra_verbose = True
outside_knowledge_allowed=True

# %%
# Gather the initial subject list 
question_subject_list = get_refined_subject_list_from_question(flashcardQuestion, kGraph,
                                                               num_cards_to_show=num_cards_to_show, verbose=verbose,
                                                              extra_verbose=extra_verbose)
# Out:
# Used tokens: 49
# Question: {Bernoulli distribution }
# Extracted key words and concepts: ["Understanding", "Science", "Knowledge", "Statistics", "Mathematics", "Probability Distribution", "Bernoulli", "Coin", "Toss", "Binomial", "Hypergeometric", "Replacement"]
#
# Question: {What are two problems with the byte pair encoding (BPE)? }
# Extracted key words and concepts: ["Knowledge", "Science", "Technology", "Computer Science", "Mathematics", "Text Compression", "Algorithm", "Byte Pair Encoding (BPE)", "BPE", "Word", "Factorization", "Space"]
#
# Question: {Expectation maximization algorithm - how can this be viewed as an optimization of the free energy? }
# Extracted key words and concepts: ["Computer Science", "Artificial Intelligence", "Mathematics", "Machine Learning", "Optimization", "Algorithm Optimization", "Expectation Maximization", "Free Energy", "Modified Free Energy", "Log Likelihood", "Latent Variable", "Entropy", "Model Parameter", "Prediction"]
#
# Question: {In a 3D metal printer, what is the wavelength of the laser? Does this matter?}
# Extracted key words and concepts: ["Science", "Engineering", "Manufacturing", "Technology", "Power", "Absorption", "Laser", "Wavelength", "3D Metal Printing"]
#
# Question: {Benefits of neural networks compared to other machine learning methods }
# Extracted key words and concepts: ["Learning", "Understanding", "Science", "Knowledge", "Artificial Intelligence", "Technology", "Machine Learning", "Data", "Neural Network", "Fine Tuning", "Concept", "Hierarchical", "Representing"]
#
# Question: {What are the two tricks used to compute the gradient of the expectation value of some function, where you are taking a gradient with respect to the parameters of the distribution?
# When can they both be used or not? }
# Extracted key words and concepts: ["Knowledge", "Science", "Data Analysis", "Mathematics", "Statistics", "Probability", "Computation", "Expectation", "Function", "Parameter", "Distribution", "Gradient", "Likelihood", "Ratio", "Sample", "Reparametrization", "Randomness"]
#
# Question: {how to concatenate two lists in python? }
# Extracted key words and concepts: ["Technology", "Problem Solving", "Computer Science", "Algorithm", "Programming", "Data Structure", "Python", "List", "Concatenation", "Extend()", "Mylist", "Newlist"]
#
# Question: {How is the alpha go Q value initialized for each node when first encountered? }
# Extracted key words and concepts: ["Computer Science", "Artificial Intelligence", "Decision Making", "Game Tree", "Best Move", "Initialization", "No Bias", "Alpha Go Q Value"]
#
# Question: {What are goals that are likely to be shared by any generated artificial general intelligence, as a corrolary or side effect of trying to achieve some other goal (convergent goals) }
# Extracted key words and concepts: ["Artificial Intelligence", "Goal-Content Integrity", "Self Preservation", "Cognition", "Resource", "Technology", "Convergent Goal", "AGI"]
#
# Question: {What was the outcome of world war 1?}
# Extracted key words and concepts: ["International Relations", "War Guilt Clause", "Arab Countries", "Ottoman Empire", "Austro-Hungarian Empire", "Germany", "Outcome", "Treaty Of Versailles", "League Of Nations", "World War 1", "Ottoman", "Arab", "Austro-Hungarian", "Versailles", "League of Nations"]
#
# Question: {How hard is it to calculate the determinant of a matrix?}
# Extracted key words and concepts:   ["Mathematics", "Algebra", "Calculation", "Matrix", "Determinant", "Complexity", "Eigenvalues", "Eigenvectors", "Cofactor Expansion", "Gaussian Elimination"]
# In graph: ['Complexity', 'Determinant', 'Algebra', 'Mathematics', 'Matrix']
# Used tokens: 42
# Question: {What is the quantum trotterization algorithm for time evolution? }
# Extracted key words and concepts: ["Knowledge", "Physics", "Science", "Mathematics", "Quantum Mechanics", "Algorithm", "Time Evolution", "Quantum Trotterization", "Matrix", "Exponentiating", "Hamiltonian"]
#
# Question: {What does the Shur decomposition ensure, and how does the algorithm proceed? }
# Extracted key words and concepts: ["Education", "Science", "Knowledge", "Linear Algebra", "Mathematics", "Algorithm", "Matrix Transformation", "Shur Decomposition", "Eigenvector", "Eigenvalue", "Subspace", "Matrix", "Column"]
#
# Question: {Determinant algorithm complexity }
# Extracted key words and concepts: ["Knowledge", "Science", "Technology", "Mathematics", "Computation", "Complexity", "Algorithm", "Determinant Algorithm", "Determinant", "Row", "Diagonal", "Product"]
#
# Question: {How are the properties of the covariance matrix similar to a hermitian matrix? }
# Extracted key words and concepts: ["Education", "Knowledge", "Learning", "Mathematics", "Science", "Matrix", "Linear Algebra", "Covariance Matrix", "Hermitian Matrix", "Diagonalizable", "Eigenvalue", "Orthogonal Eigenvector"]
#
# Question: {What are two formulas to write the determinant of a square matrix? }
# Extracted key words and concepts: ["Knowledge", "Science", "Logic", "Mathematics", "Algebra", "Square Matrix", "Laplace", "Leibniz", "Determinant", "A_i", "Sigma_i", "Sign", "Permutation", "Sum", "A_in", "Minor"]
#
# Question: {Singular Value Decomposition of a matrix:
# What is its purpose?
# What are key components of proof that it exists? }
# Extracted key words and concepts: ["Science", "Mathematics", "Algebra", "Manipulation", "Invert", "Diagonalize", "Matrix", "Decomposition", "Singular Value Decomposition", "Schur", "Spectral"]
#
# Question: {Properties of Hermitian matrices }
# Extracted key words and concepts: ["Knowledge", "Science", "Logic", "Mathematics", "Algebra", "Linear Algebra", "Matrix", "Hermitian Matrix", "Dagger", "Diagonalizable", "Shur's Decomposition", "Normal Matrix", "Eigenvalue", "Inner Product", "Conjugate", "Eigenvector", "Orthogonal"]
#
# Question: {Formula for the inverse of a matrix using the determinant }
# Extracted key words and concepts: ["Knowledge", "Logic", "Reasoning", "Science", "Problem Solving", "Mathematics", "Algebra", "Matrix Inverse", "Matrix", "Inverse", "Determinant", "Laplace", "Minor", "Entry", "Factor", "Divide"]
#
# Question: {Importance of determinants }
# Extracted key words and concepts: ["Understanding", "Learning", "Science", "Knowledge", "Algebra", "Mathematics", "Linear Algebra", "Determinant", "Matrix", "Invertible", "Importance"]
#
# Question: {What happens to the determinant of the product of two matrices }
# Extracted key words and concepts: ["Learning", "Science", "Knowledge", "Algebra", "Mathematics", "Matrix", "Determinant", "Product Determinant", "Product"]
#
# Question: {How hard is it to calculate the determinant of a matrix?}
# Extracted key words and concepts:   ["Knowledge", "Science", "Mathematics", "Algebra", "Computation", "Matrix", "Determinant", "Calculation", "Complexity", "Hardness"]
# In graph: ['Complexity', 'Science', 'Computation', 'Determinant', 'Algebra', 'Hardness', 'Knowledge', 'Mathematics', 'Matrix']

# %%
# Answer the question
flashcardAnswer = get_answer_from_question_with_subject_list(flashcardQuestion, question_subject_list, kGraph,
                                          num_cards_to_show=num_cards_to_show, 
                                                             outside_knowledge_allowed=outside_knowledge_allowed,
                                                             verbose=verbose,
                                                              extra_verbose=extra_verbose)
# Out:
# Used tokens: 94
# Professor Smith has provided the following 10 questions and answers to the class to review:
# Question: {What is the quantum trotterization algorithm for time evolution? }
# Answer: {It is a mathematical formula that lets you exponentiate a sum of matrices which do not necessarily commute, but exponentiating small fractions of them many times in repetition. This is useful for Hamiltonian time evolution in quantum mechanics, which often requires exponentiating time multiplied by a hamiltonian matrix which has many components that do not commute. }
#
# Question: {How are the properties of the covariance matrix similar to a hermitian matrix? }
# Answer: {Covariance matrix is normal and hermitian, so it is diagonalizable, and its eigenvalues are real, and different eigenvalues have orthogonal eigenvectors. }
#
# Question: {3 sat (the 3 satisfiability problem): is it or of a bunch of ands, or and of a bunch of ors?}
# Answer: {It is the and of a bunch of 3 ors.
# This is because any conjunction like (a or b) can be replaced with (a or z) and (b or bar(z)), and produce the same Sat problem (both are satisfiable at the same time, or not). In reality, if a is an "or" of two variables, and "b" is an or of 2 variables, then you can convert that "or" of 4 variables to an and of two sets of 3 variables. This is the reduction process.
# This is called the conjunctive normal form (conjunctive means "and").}
#
# Question: {What are two formulas to write the determinant of a square matrix? }
# Answer: {Laplace and Leibniz forms:Leibniz form is product over a_i,sigma_i with a new sigma for each i, and sign of permutation, summed over permutations Laplace form is sum over a_in times minus one to i plus j times determinant of minor }
#
# Question: {Singular Value Decomposition of a matrix:
# What is its purpose?
# What are key components of proof that it exists? }
# Answer: {Purpose: The singular value decomposition makes it possible to diagonalize and invert matrices, and generally makes matrix manipulation easier.
# Key components:
# The Schur decomposition shows any square matrix is able to be made upper triangular.
# The spectral theorem for square matrices shows that any normal square matrix is diagonalizable (uses Schur).
# Finally, the singular value decomposition of a matrix M is a specific application of the spectral theorem to the matrix M * M, and M M* matrix, and followed by a few steps. }
#
# Question: {Properties of Hermitian matrices }
# Answer: {A dagger equals A
# Implies it is diagonalizable (because of Shurs decomposition and properties of a normal matrix).
# All eigenvalues are real because you can take inner product with eigenvectors, and then conjugate it, and its the same.
# All eigenvectors with differing eigenvalues are orthogonal. }
#
# Question: {Formula for the inverse of a matrix using the determinant }
# Answer: {The inverse formula uses the laplace form of the matrix determinant. One needs the determinants of the minors and then places these in the entries of the matrix inverse in a certain way with factors of -1 as well, and divides by the determinant.}
#
# Question: {Importance of determinants }
# Answer: {Tells you if a matrix is invertible }
#
# Question: {Determinant algorithm complexity }
# Answer: {It's n cubed. You add and subtract rows to each other row until it's upper diagonal. Because that doesn't change the determinant it's the same determinant at end and that's the product of diagonals. }
#
# Question: {What happens to the determinant of the product of two matrices }
# Answer: {It's the product of determinants. }
#
# Professor Smith has asked us to try to answer one final question. If we are not satisfied with our ability to answer the question fully and completely, then we must say so. To indicate this to Professor Smith, we must add an additional statement "Suggested further questions: [your text here]" to suggest what else we would need to know to answer the question fully. These suggested further questions should be sufficiently detailed to be understood and answered without additional context or explanation. In general, the response must be concise, simple, and direct. In this answer, we are allowed to use both information in the last 10 questions and answers, as well as prior knowledge. However, when new evidence conflicts with prior knowledge, we should trust the new evidence. We may not be able to answer the question.
#
# Question: Question: {How hard is it to calculate the determinant of a matrix?}
# Answer:   Calculating the determinant of a matrix is an algorithm with complexity of O(n^3). It is possible to calculate the determinant of a matrix using the Laplace formula, which involves calculating the determinants of the minors of the matrix. Suggested further questions: What is the Laplace formula for calculating the determinant of a matrix? What is the complexity of the Laplace formula? What is the Schur decomposition? What is the spectral theorem?

# %%
generated_further_question_list = get_suggested_further_questions_from_question_and_subject_list(flashcardQuestion, question_subject_list, kGraph,  
                                                               num_seed_cards_to_show=4,
                                                               num_related_cards_to_show=5,
                                                               num_questions_to_generate=4,
                                                                                         increasing_abstraction=False,
                                                                                                 temperature=0.25,
                                                               verbose=verbose,
                                                              extra_verbose=extra_verbose)
# Out:
# Used tokens: 73
# Professor Smith has provided the following groups of questions to the class to review. Within each group of questions, successive questions cover topics of decreasing abstraction and more detail. All questions are meant to be sufficiently detailed to be understandable without further context:
#
# Related questions in order of decreasing abstraction and more detail:
# Q: {What are the 4 types of T cell states relevant to cancer immunotherapy?}
# Q: {For cancer immunotherapy with checkpoint blockade, what is the fraction of patients in early ipilimumab trials that responded? }
# Q: {What happened to the approval process for cancer drugs at the FDA around 2005 that didn't happen in other areas of disease?}
# Q: {What are the two major categories of cancer immunotherapy currently? }
# Q: {For cancer immunotherapy with checkpoint blockade, what has the average life expectancy of late stage melanoma gone from, between around 2005 and now?}
#
# Related questions in order of decreasing abstraction and more detail:
# Q: {Why was pixelVAE (a blend of pixelCNN and VQ-VAE) better than either individually? }
# Q: {What was I originally confused about regarding VQ-VAE architectures? How does it turn out they are actually able to overcome this problem? }
# Q: {What is the main difference in the structure of the latent space for VQ-VAE compared to VAE? (vector quantized VAE vs normal VAE) }
# Q: {In CS294 (Berkeley) - Deep Unsupervised learning, what is the relation between VAE, VQ-VAE, and PixelVAE?}
# Q: {What is the major difference between variational autoencoders (VAEs) and flow models? }
#
# Related questions in order of decreasing abstraction and more detail:
# Q: {How is the predictive upper confidence tree algorithm (PUCT) different from UCT? }
# Q: {What are the three possible physical implementations to use in encoding value in reinforcement learning? }
# Q: {What is inverse reinforcement learning? }
# Q: {What is the regularized nash dynamics algorithm used in the stratego paper by Deepmind? }
# Q: {In the stratego paper, what is the regularized nash dynamics algorithm most similar to in other reinforcement learning algorithms? }
#
# Related questions in order of decreasing abstraction and more detail:
# Q: {What does the CTLA-4 receptor do on T cells in the human immune system?
# What do tumors do to it?}
# Q: {For cancer immunotherapy with checkpoint blockade, what is the fraction of patients in early ipilimumab trials that responded? }
# Q: {What are the 4 types of T cell states relevant to cancer immunotherapy?}
# Q: {What are the two major categories of cancer immunotherapy currently? }
# Q: {What happened to the approval process for cancer drugs at the FDA around 2005 that didn't happen in other areas of disease?}
#
# Related questions in order of decreasing abstraction and more detail:
# Q: {How hard is it to calculate the determinant of a matrix?}
# Q: { What is the definition of a determinant?}
# Q: {What is the formula for calculating the determinant of a 3x3 matrix?}
# Q: {What is the Laplace expansion method for calculating the determinant of a matrix?}
# Q: {What is the formula for calculating the determinant of a 2x2 matrix?}

# %%
# Enhance the detail of the question
flashcardQuestion_enhanced = get_enhanced_question_from_question_and_subject_list(flashcardQuestion, question_subject_list, kGraph,
                                                        num_cards_to_show=num_cards_to_show, verbose=verbose,
                                                              extra_verbose=extra_verbose)
# Out:
# Used tokens: 16
# Professor Smith has provided the following questions to the class to review:
# Question: {What is the quantum trotterization algorithm for time evolution? }
#
# Question: {How are the properties of the covariance matrix similar to a hermitian matrix? }
#
# Question: {3 sat (the 3 satisfiability problem): is it or of a bunch of ands, or and of a bunch of ors?}
#
# Question: {What are two formulas to write the determinant of a square matrix? }
#
# Question: {Singular Value Decomposition of a matrix:
# What is its purpose?
# What are key components of proof that it exists? }
#
# Question: {Properties of Hermitian matrices }
#
# Question: {Formula for the inverse of a matrix using the determinant }
#
# Question: {Importance of determinants }
#
# Question: {Determinant algorithm complexity }
#
# Question: {What happens to the determinant of the product of two matrices }
#
#
# A student is currently studying the following question:
# Question: {How hard is it to calculate the determinant of a matrix?}
#
# We have been asked to rephrase this question to better test the students knowledge in as much detail as possible. The rephrased question must test the exact same information as the original question. It must be concise, simple, and direct. Rephrased question:
#
# What is the computational complexity of calculating the determinant of a matrix?

# %% [markdown]
# #### Make entire flashcard better

# %%
# Enhance the detail of the question
cardID = 490
flashcardQuestion = kGraph.cards[cardID].question
flashcardAnswer = kGraph.cards[cardID].answer
# flashcardConceptList = kGraph.cards[cardID].concepts.get_concepts_list()
print(flashcardQuestion)
# print(flashcardConceptList)
print(flashcardAnswer)
# Out:
# What is Jensen-Shannon divergence, and what properties of basic Kulback Liebler divergence make it useful.
# What is it used in (what type of reinforcement learning?)
# Jensen shannon is Kulback Liebler divergence of p from (p+q)/2 plus Kulback Liebler divergence of q from (p+q)/2, averaged
# One portion of this punishes the model having predictions where there isn't data, the other portion punishes the data existing where the model is not
# Normal maximum likelihood estimation only pushes model to predict data. It doesn't penalize predicting things that aren't the data.
# Jensen Shannon divergence is used for generative adversarial networks.

# %%
# Gather the initial subject list 
question_subject_list = get_refined_subject_list_from_question(flashcardQuestion, kGraph,
                                                               num_cards_to_show=num_cards_to_show, verbose=verbose,
                                                              extra_verbose=extra_verbose)
# Out:
# Used tokens: 65
# Question: {Jacob Andreas 2022: "Language Models as Agent Models"
# What are the 3 examples given in the paper to show how LMs construct agent models?}
# Extracted key words and concepts: ["Science", "Computer Science", "Data Science", "Artificial Intelligence", "Machine Learning", "Natural Language Processing", "Agent Model", "Prompt Engineering", "Online Review", "Language Model", "Toy Model", "Professor Smith", "Alternative Medicine", "Amazon"]
#
# Question: {How is the predictive upper confidence tree algorithm (PUCT) different from UCT? }
# Extracted key words and concepts: ["Science", "Computer Science", "Technology", "Artificial Intelligence", "Machine Learning", "Algorithm", "Reinforcement Learning", "PUCT", "UCT", "Feedback", "Confidence", "Probability", "Policy", "Exploration", "N", "N_i"]
#
# Question: {What is the definition of the odds of an event occuring? }
# Extracted key words and concepts: ["Knowledge", "Science", "Reasoning", "Mathematics", "Statistics", "Event", "Probability", "Odd", "Formula"]
#
# Question: {What is the theoretical formula of the exact target function for a variational autoencoder?
# What is the difficult part of using this? }
# Extracted key words and concepts: ["Science", "Technology", "Machine Learning", "Artificial Intelligence", "Maximization", "Target Function", "Formula", "Log", "Computation", "VAE"]
#
# Question: {How is the metric of disruptive papers compared to consolidating papers similar to one of Nielsen's ideas about science processes? }
# Extracted key words and concepts: ["Science Process", "Nielsen's Idea", "Problem Creator", "Problem Solver", "Disruptive Paper", "Consolidating Paper", "Metric", "Disruptive", "Consolidating", "Paper", "Nielsen", "Problem", "Creator", "Solver"]
#
# Question: {Regardless of the phrasing of the definition of Kulback Liebler divergence:
# How should one remember, in the resulting formula, which distribution is included in the term which has the usual Shannon entropy form, and which distribution is only present in the cross entropy term? }
# Extracted key words and concepts: ["Learning", "Science", "Knowledge", "Mathematics", "Statistics", "Probability Distribution", "Kulback Liebler Divergence", "Shannon Entropy", "Cross Entropy", "Distribution", "Surprise"]
#
# Question: {What are the different types of outputs from a reinforcement learning algorithm to use to choose the action to take for the global policy? }
# Extracted key words and concepts: ["Computer Science", "Machine Learning", "Artificial Intelligence", "Algorithm", "Policy", "Output", "Reinforcement Learning", "Value Function", "Look Ahead", "Best Value", "Q Function", "Optimal Action", "Policy Probability", "Action Sampling", "MCTS", "Visit Count"]
#
# Question: {What is the prototypical example of a 1D flow model?}
# Extracted key words and concepts: ["Mathematics", "Probability", "Density", "Mapping", "Sampling", "1D Flow Model", "Cumulative Density Function", "Normalizing Flow", "Flow Model", "CDF", "X", "Z", "PDF", "Derivative"]
#
# Question: {What are two examples of metascience entrepeneurs that already exist? }
# Extracted key words and concepts: ["Innovation", "Science", "Technology", "Existing Entity", "Business", "Example", "Metascience Entrepreneur", "Metascience", "Entrepreneur", "Arxiv", "Physicist", "FRO"]
#
# Question: {What uses/example cases were shown for the perceiver architecture (Deepmind)? }
# Extracted key words and concepts: ["Science", "Computer Science", "Technology", "Artificial Intelligence", "Data Science", "Nlp", "Encoding", "Embedding", "Perceiver", "BPE", "NLP", "Deepmind"]
#
# Question: {What is Jensen-Shannon divergence, and what properties of basic Kulback Liebler divergence make it useful.
# What is it used in (what type of reinforcement learning?) }
# Extracted key words and concepts:   ["Mathematics", "Statistics", "Probability", "Kulback Liebler Divergence", "Jensen-Shannon Divergence", "Properties", "Reinforcement Learning", "Divergence", "KL", "JS", "Symmetric", "Distance", "Metric"]
# In graph: ['Statistics', 'Probability', 'Metric', 'Reinforcement Learning', 'KL', 'Divergence', 'Kulback Liebler Divergence', 'Distance', 'Mathematics']
# Used tokens: 57
# Question: {What are the steps involved in contrastive divergence? }
# Extracted key words and concepts: ["Mathematics", "Machine Learning", "Statistics", "Neural Network", "Probability", "Estimation", "Boltzmann Machine Model", "Maximum Likelihood Estimation", "Contrastive Divergence", "Boltzmann", "MLE", "Divergence", "Visible", "Hidden", "Sample", "MC"]
#
# Question: {Chi-squared distribution }
# Extracted key words and concepts: ["Knowledge", "Science", "Data Analysis", "Mathematics", "Probability", "Distribution", "Statistics", "Chi-Squared", "Normally Distributed", "Standard Deviation", "Formula", "Pdf", "Polyomial", "Exponential", "Cdf", "Confidence Interval"]
#
# Question: {How is the Fisher information related to the certianty on the parameters of a distribution? }
# Extracted key words and concepts: ["Knowledge", "Mathematics", "Science", "Statistics", "Probability", "Measurement", "Distribution", "Fisher Information", "Fisher", "Certainty", "Parameter", "Variance"]
#
# Question: {What is Jensen-Shannon divergence, and what properties of basic Kulback Liebler divergence make it useful.
# What is it used in (what type of reinforcement learning?) }
# Extracted key words and concepts: ["Reinforcement Learning", "Maximum Likelihood", "Generative Adversarial Networks", "Model", "Data", "Divergence", "Probability", "Jensen-Shannon", "Kulback Liebler", "Generative Adversarial Network"]
#
# Question: {What is the solution to deal with the large randomness and local minima in strategy in poker (to bet randomly to only lose half the time, rather than more than half), as a reinforcement learning problem? }
# Extracted key words and concepts: ["Mathematics", "Artificial Intelligence", "Probability", "Machine Learning", "Game Theory", "Strategy", "Reinforcement Learning", "Poker", "Randomness", "Minima", "Overfitting", "Regularization"]
#
# Question: {Log-normal distribution }
# Extracted key words and concepts: ["Knowledge", "Statistics", "Science", "Probability", "Mathematics", "Distribution", "Random Variable", "Log-normal", "Log-Normal", "Exponentiation", "Pdf", "Poisson", "Gibrat's Law", "Log", "Product", "Central Limit Theorem", "Gaussian"]
#
# Question: {In t-sne, what is the original measurement that controls the final distribution of points? }
# Extracted key words and concepts: ["Mathematics", "Data Analysis", "Statistics", "Visualization", "Measurement", "Similarity", "Gaussian", "Entropy", "T-Sne", "T-SNE", "Point I", "Point J", "Relative Distance"]
#
# Question: {Regardless of the phrasing of the definition of Kulback Liebler divergence:
# How should one remember, in the resulting formula, which distribution is included in the term which has the usual Shannon entropy form, and which distribution is only present in the cross entropy term? }
# Extracted key words and concepts: ["Learning", "Science", "Knowledge", "Mathematics", "Statistics", "Probability Distribution", "Kulback Liebler Divergence", "Shannon Entropy", "Cross Entropy", "Distribution", "Surprise"]
#
# Question: {How does the t-sne reconstruction process intentionally differ from the original measurement of the distribution of points in the high dimensional space? }
# Extracted key words and concepts: ["Similarity", "Metric", "Distance", "Laplacian", "Gaussian", "Proximity", "Distribution", "Plot", "Goal", "Entropy", "Probability", "Point", "High Dimensional Space", "Measurement", "Reconstruction", "Process", "T-SNE", "T-Sne"]
#
# Question: {How to remember the phrasing of the definition of Kulback Liebler divergence?
# The Kulback Liebler divergence is usually phrased as "from distribution Q to distribution P".
# How should one remember, in the resulting formula, which distribution is included in the term which has the usual Shannon entropy form, and which distribution is only present in the cross entropy term? }
# Extracted key words and concepts: ["Knowledge", "Science", "Data Analysis", "Mathematics", "Statistics", "Divergence", "Probability Distribution", "Kulback Liebler", "Distribution", "Q", "P", "Shannon Entropy", "Cross Entropy", "Ground Truth"]
#
# Question: {What is Jensen-Shannon divergence, and what properties of basic Kulback Liebler divergence make it useful.
# What is it used in (what type of reinforcement learning?) }
# Extracted key words and concepts:   ["Reinforcement Learning", "Maximum Likelihood", "Generative Adversarial Networks", "Model", "Data", "Divergence", "Probability", "Jensen-Shannon", "Kulback Liebler", "Generative Adversarial Network"]
# In graph: ['Model', 'Probability', 'Generative Adversarial Network', 'Kulback Liebler', 'Reinforcement Learning', 'Data', 'Divergence', 'Jensen-Shannon', 'Maximum Likelihood', 'Generative Adversarial Networks']

# %%
# Make updated phrasing
flashcard_enhanced = get_enhanced_flashcard_from_question_and_answer_and_subject_list(flashcardQuestion, flashcardAnswer, 
                                                                                      question_subject_list, kGraph,
                                                        num_cards_to_show=num_cards_to_show, verbose=verbose,
                                                              extra_verbose=extra_verbose)
# Out:
# Used tokens: 103
# Professor Smith has provided the following question and answer pairs to the class to review:
# Question: {What are the steps involved in contrastive divergence? }
# Answer: {We want to sample the energy of a Boltzmann machine model (on average) for computing a gradient in MLE.
# To do so, we start with a real sample in the visible layer, get probability sample of hidden layer, then go back and forth, until we converge to something representative of the model (MC estimate). }
#
# Question: {What is the likelihood function of some observed data and probability distribution? }
# Answer: {The likelihood function of some observed data with some parametrized probability distribution is a function of the parameters of the distribution. It is the probability of observing the data given the parameters. }
#
# Question: {What is a maximum likelihood estimator (MLE) }
# Answer: {The maximum likelihood estimator (MLE) of some parameters of a distribution is the value of all possible parameters that maximizes the likelihood of the data that was observed. }
#
# Question: {Expectation maximization algorithm - describe the basic setup and steps }
# Answer: {The overall goal is to maximize the log likelihood of data within the structure of a given model.
# Expectation maximization assumes that latent variables exist which describe the data (such as clusters of data being drawn from similar groups)
# The algorithm assigns each datapoint to a cluster with a given probability, then updates the parameters of the clusters to optimize overall data reconstruction, and then reassigns datapoints to their new optimal clusters, and then repeats }
#
# Question: {In t-sne, what is the original measurement that controls the final distribution of points? }
# Answer: {The original measurement is a similarity metric from point i to point j.
# This is the probability that point i would pick point j as it's nearest neighbor based on their relative distance plugged into a Gaussian with some adjusted Gaussian width.
# For each point i, the gaussian width is adjusted so that each point's nearest neighbor distribution has the same entropy distribution as all the other points. }
#
# Question: {How does the t-sne reconstruction process intentionally differ from the original measurement of the distribution of points in the high dimensional space? }
# Answer: {The final setup uses a similarity metric based on distance which is a Laplacian rather than a Gaussian.  (I think this is the t-distribution part of the name of t-sne.)
# This is crucial, because it is what allows us to move all the very far away points into closer proximity, and the close points into more even distribution; it moves everything into the middle region. This makes it easier to see everything on one plot.
# -----
# As a reminder, the overal goal is that it tries to reproduce the nearest neighbor distribution entropy for each point, but it does so with a new probability metric. }
#
# Question: {What does t-sne stand for in machine learning? }
# Answer: {t-distributed stochastic neighbor embedding }
#
# Question: {For t-sne reconstruction, what is the cost function which is minimized to best reconstruct the distribution of the original datapoints in a lower dimensional space? }
# Answer: {The cost function used is the Kulback Liebler divergence from the new distribution Q to the old distribution P of the similarities between datapoints (P has a gaussian similarity metric based on distance (symmetrized from the measurement of i to j and from j to i), and Q has the t-distributed similarity metric (also symmetrized from i to j and from j to i)) }
#
# Question: {How to remember the phrasing of the definition of Kulback Liebler divergence?
# The Kulback Liebler divergence is usually phrased as "from distribution Q to distribution P".
# How should one remember, in the resulting formula, which distribution is included in the term which has the usual Shannon entropy form, and which distribution is only present in the cross entropy term? }
# Answer: {The distribution you are comparing "to" should be thought of as the ground truth distribution you really believe is correct. Therefore you are measuring the divergence from the other thing, to that ground truth.
# On wikipedia: "Usually P represents the data, the observations, or a measured probability distribution. Distribution Q represents instead a theory, a model, a description or an approximation of P." }
#
# Question: {What is Jensen-Shannon divergence, and what properties of basic Kulback Liebler divergence make it useful.
# What is it used in (what type of reinforcement learning?) }
# Answer: {Jensen shannon is Kulback Liebler divergence of p from (p+q)/2 plus Kulback Liebler divergence of q from (p+q)/2, averaged
# One portion of this punishes the model having predictions where there isn't data, the other portion punishes the data existing where the model is not
# Normal maximum likelihood estimation only pushes model to predict data. It doesn't penalize predicting things that aren't the data.
# Jensen Shannon divergence is used for generative adversarial networks.}
#
#
# A student is currently studying the following question and answer pair:
# Question: {What is Jensen-Shannon divergence, and what properties of basic Kulback Liebler divergence make it useful.
# What is it used in (what type of reinforcement learning?) }
# Answer: {Jensen shannon is Kulback Liebler divergence of p from (p+q)/2 plus Kulback Liebler divergence of q from (p+q)/2, averaged
# One portion of this punishes the model having predictions where there isn't data, the other portion punishes the data existing where the model is not
# Normal maximum likelihood estimation only pushes model to predict data. It doesn't penalize predicting things that aren't the data.
# Jensen Shannon divergence is used for generative adversarial networks.}
#
# We have been asked to rephrase this question and answer pair to improve its quality. The rephrased question and answer must test the exact same information as the original question. It must be concise, simple, and direct. When applicable, it should summarize ideas into numbered lists, or structured notes, to show an organized hierarchy of ideas.
#
# Rephrased version:
# Question: What is the purpose of Jensen-Shannon divergence and how is it used in reinforcement learning?
# Answer: Jensen-Shannon divergence is a combination of two Kulback Liebler divergences, which is used to measure the difference between two probability distributions. It is useful because it penalizes the model for predicting things that are not in the data, unlike maximum likelihood estimation which only pushes the model to predict data. It is used in generative adversarial networks, a type of reinforcement learning.

# %% [markdown]
# ## Cluster cards into a hierarchy

# %%
# Functions for first clustering within a similarity metric

def get_ordered_IDs_by_similarity_to_ID(similarity_metric, cluster_IDs_list, target_ID):
    similarity_vals_presort = similarity_metric[target_ID][cluster_IDs_list]
    ordered_ID_inds = np.flip(np.argsort(similarity_vals_presort))
    ordered_IDs = np.array(cluster_IDs_list)[ordered_ID_inds]
    return ordered_IDs

def get_sub_similarity_metric(similarity_metric, sub_inds_list):
    return np.copy(similarity_metric[sub_inds_list][:,sub_inds_list])

def get_cluster_quality(similarity_metric, cluster_IDs_list, target_ID, cluster_size_scaling=4.0):
    
    def get_log_ratio_vals(submat_self_similarities):

        def get_array_without_diag(A):
            return A[~np.eye(A.shape[0],dtype=bool)].reshape(A.shape[0],-1)
        # for mean values, may want to remove diagonal
        submat_self_similarities_offdiag = get_array_without_diag(submat_self_similarities)
        off_diag_mean_vals = submat_self_similarities_offdiag.mean(axis=0)

        min_vals = submat_self_similarities.min(axis=0)
        # mean_vals = submat_self_similarities.mean(axis=0)

        zip_min_mean_vals = zip(min_vals, off_diag_mean_vals)
        log_ratio_vals = np.array([np.log(min_val/mean_val) 
                                   for min_val, mean_val in zip_min_mean_vals])
        return log_ratio_vals
    
    similarities_to_target = similarity_metric[target_ID][cluster_IDs_list]
    avg_similarity_to_target = np.average(similarities_to_target)
    
    submat_of_cluster = get_sub_similarity_metric(similarity_metric, cluster_IDs_list)
    log_ratio_vals = get_log_ratio_vals(submat_of_cluster)
    log_scaling = 1.0/cluster_size_scaling
    return avg_similarity_to_target * np.log(len(cluster_IDs_list)) + log_scaling * np.sum(log_ratio_vals)

def get_best_approximate_cluster_relative_to_ID_with_desired_size(similarity_metric, target_ID, 
                                                         cluster_size_scaling=4.0, 
                                                         verbose=False):
    max_IDs_to_check = 50
    ordered_IDs = get_ordered_IDs_by_similarity_to_ID(similarity_metric, range(len(similarity_metric)), target_ID)

    # Get approximate best first order cluster 
    quality_vals = []
    ordered_ind_max_vals = []
    ordered_ind_sets = []
    for ordered_ind_max in range(max_IDs_to_check):
        cluster_IDs_list = ordered_IDs[0:ordered_ind_max+1]
        quality_metric = get_cluster_quality(similarity_metric, cluster_IDs_list, target_ID, 
                                                               cluster_size_scaling=cluster_size_scaling)
        # Append measurement
        quality_vals.append(quality_metric)
        ordered_ind_max_vals.append(ordered_ind_max)
        ordered_ind_sets.append(cluster_IDs_list)
        
        if quality_metric < 0: # Then we will probably just get worse from here. Stop
            break
    
    # Find argmax 
    best_quality_ind = np.argmax(quality_vals)
    best_set_initial_pass = ordered_ind_sets[best_quality_ind]
    current_best_quality_val = quality_vals[best_quality_ind]
    
    if verbose:
        print('Initial results, with best quality value:', current_best_quality_val, 
              ' and set:', best_set_initial_pass)
        plt.plot(ordered_ind_max_vals, quality_vals)
        plt.show()
        
    return best_set_initial_pass

def get_best_revised_cluster_relative_to_ID_with_desired_size(similarity_metric, target_ID, best_set_initial_guess, 
                                             num_max_revisit_passes=50,
                                             cluster_size_scaling=4.0, 
                                             verbose=False):
    how_much_larger_set_to_check = 2
    
    best_set = best_set_initial_guess
    ordered_IDs = get_ordered_IDs_by_similarity_to_ID(similarity_metric, range(len(similarity_metric)), target_ID)
    max_IDs_to_check = len(best_set) * how_much_larger_set_to_check

    # Loop through and check if adding or removing single cards is worse or better. 
    for _iteration in range(num_max_revisit_passes):       
        
        current_best_quality_val = get_cluster_quality(similarity_metric, list(best_set), target_ID,
                                                                       cluster_size_scaling=cluster_size_scaling)
        if verbose:
            print('iteration number', _iteration, ' with current best set: ', best_set, ' and best quality val', current_best_quality_val)
        
        quality_vals = []
        testID_vals = []
        new_test_sets = []
        for ordered_ind, testID in enumerate(ordered_IDs[0:max_IDs_to_check]):
            new_test_set = np.copy(best_set)
            if testID in best_set:
                new_test_set = np.setdiff1d(new_test_set, testID)
            else:
                new_test_set = np.append(new_test_set, testID)

            if len(new_test_set) > 0: # only consider new sets that have nonzero size
                cluster_IDs_list = list(new_test_set)
                quality_metric = get_cluster_quality(similarity_metric, cluster_IDs_list, target_ID,
                                                                       cluster_size_scaling=cluster_size_scaling)

                quality_vals.append(quality_metric)
                testID_vals.append(testID)
                new_test_sets.append(new_test_set)

        
        if np.max(quality_vals - current_best_quality_val) > 0:
            changed_ID = testID_vals[np.argmax(quality_vals)]
            if verbose:
                if changed_ID in best_set:
                    print('  removed card ',changed_ID)
                else:
                    print('  added card ',changed_ID)
            best_set = new_test_sets[np.argmax(quality_vals)]
            current_best_quality_val = np.max(quality_vals)
        else:
            # There was no improvement for any proposed change, so stop iterating 
            break
        
    ordered_IDs_list_result = get_ordered_IDs_by_similarity_to_ID(similarity_metric, list(best_set), target_ID)

    return ordered_IDs_list_result


def get_best_first_order_cluster_relative_to_ID_with_desired_size(similarity_metric, target_ID, 
                                             num_max_revisit_passes=50,
                                             cluster_size_scaling=4.0, 
                                             verbose=False):

    best_set_initial_pass = get_best_approximate_cluster_relative_to_ID_with_desired_size(similarity_metric, target_ID, 
                                                                     cluster_size_scaling=cluster_size_scaling,
                                                                     verbose=verbose)
    
    ordered_IDs_result = get_best_revised_cluster_relative_to_ID_with_desired_size(similarity_metric, target_ID, best_set_initial_pass, 
                                                 num_max_revisit_passes=num_max_revisit_passes,
                                                 cluster_size_scaling=cluster_size_scaling, 
                                                 verbose=verbose)
    
    return ordered_IDs_result

# %%
# Function for high level clustering of a similarity metric

def remove_complete_subsets(clusters_IDgroups_list):
    # Removes clusters that are a complete subset of another cluster.
    # Returns clusters in order of decreasing size
    
    # Get clusters in order of increasing size. 
    cluster_inds_increasing_size = np.argsort(np.array([len(cluster_IDgroup) for cluster_IDgroup in clusters_IDgroups_list]))
    ordered_clusters_IDgroups_list = [clusters_IDgroups_list[cluster_ind] for cluster_ind in cluster_inds_increasing_size]

    # For each cluster, loop through other clusters and check if its a strict subset
    # If it is not a strict subset of any, then keep it in the final list. 
    final_clusters_IDgroups_list = []
    for cluster_ind_test, cluster_IDgroup_test in enumerate(ordered_clusters_IDgroups_list):
        is_subset = False
        for cluster_IDgroup_potential_superset in ordered_clusters_IDgroups_list[cluster_ind_test + 1:]: # only loop over larger ones
            if set(cluster_IDgroup_test).issubset(set(cluster_IDgroup_potential_superset)):
                is_subset = True 
        if not is_subset:
            final_clusters_IDgroups_list.append(cluster_IDgroup_test)
    
    final_clusters_IDgroups_list.reverse() # report in order of decreasing size at end 
    
    return final_clusters_IDgroups_list

def get_best_clusters_with_desired_size(similarity_metric,
                                             meta_cluster_size_scaling=0.75, # sets the overall precision of clusters. Less precise = larger clusters
                                             verbose=False):
    
    # Finds best clusters by scanning the sensitivity of the first order clustering metric
    # and finding point where it is best quality. 

    # Set up some basic parameters 
    cluster_score_tolerance = 0.02
    cluster_size_scaling_pow_min = -5
    cluster_size_scaling_pow_max = 6
    cluster_size_scaling_arr = 2 ** np.linspace(cluster_size_scaling_pow_min, cluster_size_scaling_pow_max, 
                                                2*(cluster_size_scaling_pow_max - cluster_size_scaling_pow_min + 1))

    significant_clusters_unique_tuple_id_list = []
    significant_clusters_IDgroups_list = []
    significant_cluster_score_list = []

    for target_ID in range(len(similarity_metric)):

        cluster_score_vs_cluster_size = []
        cluster_ID_list_vs_cluster_size = []
        prev_scaled_cluster_score = -1 # for reference 

        # Loop through various low level clustering target sizes to find one with best exclusion around this ID
        for cluster_size_scaling in cluster_size_scaling_arr:
            proposed_ID_list_this_cluster_size = get_best_first_order_cluster_relative_to_ID_with_desired_size(similarity_metric, target_ID, 
                                                             cluster_size_scaling=cluster_size_scaling, 
                                                             verbose=verbose)

            # Get clusters around each of the proposed items in this new cluster 
            proposed_reverse_ID_sets_this_cluster_size = []
            for proposed_ID in proposed_ID_list_this_cluster_size:
                proposed_reverse_ID_list_this_cluster_size = get_best_first_order_cluster_relative_to_ID_with_desired_size(similarity_metric, proposed_ID, 
                                                                 cluster_size_scaling=cluster_size_scaling, 
                                                                 verbose=verbose)
                proposed_reverse_ID_sets_this_cluster_size.append(proposed_reverse_ID_list_this_cluster_size)

            # Gather metric for success rate
            proposed_num_IDs = len(proposed_ID_list_this_cluster_size)
            inclusion_success_rate_list = []
            exclusion_success_rate_list = []

            for proposed_reverse_ID_set in proposed_reverse_ID_sets_this_cluster_size:
                reference_set = set(proposed_ID_list_this_cluster_size)
                test_set = set(proposed_reverse_ID_set)
                extra_IDs = test_set.difference(reference_set)
                missing_IDs = reference_set.difference(test_set)

                min_success_val_cutoff = 1e-10
                exclusion_success_rate_list.append(max(1.0 -len(extra_IDs) / proposed_num_IDs, min_success_val_cutoff))
                inclusion_success_rate_list.append(max(1.0 -len(missing_IDs) / proposed_num_IDs, min_success_val_cutoff))

            exclusion_success_rate_list = np.array(exclusion_success_rate_list)
            inclusion_success_rate_list = np.array(inclusion_success_rate_list)
            inclusion_log_success_min = np.log(np.min(inclusion_success_rate_list))
            exclusion_log_success_min = np.log(np.min(exclusion_success_rate_list))
            meta_log_scaling = 1.0/meta_cluster_size_scaling

            scaled_cluster_score = np.log(proposed_num_IDs)  + meta_log_scaling * (inclusion_log_success_min + exclusion_log_success_min)/2.0

            cluster_score_vs_cluster_size.append(scaled_cluster_score)
            cluster_ID_list_vs_cluster_size.append(proposed_ID_list_this_cluster_size)

            if scaled_cluster_score < prev_scaled_cluster_score : # probably not going to get better
                break
            prev_scaled_cluster_score = scaled_cluster_score

        # Gather result and take best quality cluster within tolerance
        cluster_score_vs_cluster_size = np.array(cluster_score_vs_cluster_size)
        max_cluster_score = np.max(cluster_score_vs_cluster_size)
        cluster_ind_with_max_score = np.max(np.where(np.abs(cluster_score_vs_cluster_size - max_cluster_score) < cluster_score_tolerance)[0])
        best_cluster_ID_list = cluster_ID_list_vs_cluster_size[cluster_ind_with_max_score]

        if max_cluster_score < 0:  # Ignore really bad clusters. Replace with the original ID only. 
            max_cluster_score = 0
            best_cluster_ID_list = [target_ID]

        cluster_unique_tuple_id = tuple(sorted(best_cluster_ID_list)) # for checking if this exact cluster is already found at this level
        

        if not (cluster_unique_tuple_id in significant_clusters_unique_tuple_id_list):
            # Then we found a new cluster, so keep it 
            significant_clusters_unique_tuple_id_list.append(cluster_unique_tuple_id)
            significant_clusters_IDgroups_list.append(best_cluster_ID_list)
            significant_cluster_score_list.append(max_cluster_score)
            
    # Lastly, loop back through and check if each cluster is a strict subset of all the other ones. 
    significant_clusters_IDgroups_list = remove_complete_subsets(significant_clusters_IDgroups_list)
    
    print('  Clusters identified: ', len(significant_clusters_IDgroups_list))

    # significant_clusters_IDgroups_list is a list of the IDs relative to THIS similarity metric! 
    return significant_clusters_IDgroups_list

# %%
# Functions to extract amd combine embeddings, and similarity metric

# def get_emb_vec_list_from_cluster_cardIDs(prev_significant_clusters_cardIDs_list,
#                                            intersection_threshold_amount, knowledgeGraph):
#     # Goes through and gets the ID group for each new cluster
#     # Then combines data from all stuff contained in that group. 

#     global_emb_vec_list = []
#     for cluster_cardIDs in prev_significant_clusters_cardIDs_list:
#         # Gather stuff from within this card 
#         emb_vec_list = [knowledgeGraph.cards[_cardID].embedding_vector_trimmed for _cardID in cluster_cardIDs]
#         cluster_emb_vec_untrimmed = emb_vec_intersection_with_threshold(emb_vec_list, knowledgeGraph, 
#                                                                         intersection_threshold_amount)
#         cluster_emb_vec = trim_embedding_vector(cluster_emb_vec_untrimmed)
#         global_emb_vec_list.append(cluster_emb_vec)
        
#     return global_emb_vec_list


def get_emb_vec_list_from_cluster_cardIDs(prev_significant_clusters_cardIDs_list, knowledgeGraph):
    # Goes through and gets the ID group for each new cluster
    # Then combines data from all stuff contained in that group. 

    global_emb_vec_list = []
    for cluster_cardIDs in prev_significant_clusters_cardIDs_list:
        
        # Gather unique concepts mentioned anywhere in this cluster. 
            # If mentioned multiple times, only counts once
        concept_lists = [knowledgeGraph.cards[_cardID].concepts.get_concepts_list() for _cardID in cluster_cardIDs]
        concept_set = set()
        for concept_list in concept_lists:
            concept_set.update(set(concept_list))
        concept_list = list(concept_set)
        
        # Get embedding vector 
        cluster_emb_vec_untrimmed = emb_vec_weighted_union_of_nodes(concept_list, knowledgeGraph)
        cluster_emb_vec = trim_embedding_vector(cluster_emb_vec_untrimmed)
        global_emb_vec_list.append(cluster_emb_vec)
        
    return global_emb_vec_list

def get_similarity_metric_from_emb_vec_list(emb_vec_list):
    similarity_metric = np.zeros((len(emb_vec_list), len(emb_vec_list)))

    for ind1, emb_vec1 in enumerate(emb_vec_list):
        similarity_metric[ind1,ind1] = 1.0  # diag is 1 by definition
        for ind2, emb_vec2 in enumerate(emb_vec_list):
            if ind2 > ind1:
                inner_prod = emb_vec_inner_product(emb_vec1, emb_vec2)
                similarity_metric[ind1, ind2] = (inner_prod + 1e-13)/(1.0 + 1e-13)
                similarity_metric[ind2, ind1] = (inner_prod + 1e-13)/(1.0 + 1e-13)
                
    return similarity_metric

def get_new_cluster_cardIDs(this_level_IDgroups, prev_level_cluster_cardIDs):
    # Takes IDs of clusters in the similarity metric, and the cardIDs corresponding to those IDs from the previous layer,
    # and returns the new list of cardIDs in the new clusters
    
    this_level_cluster_cardIDs = []
    for cluster_IDgroup in this_level_IDgroups:
        cardID_set = set()
        for similarityID in cluster_IDgroup:
            cardID_set.update(set(prev_level_cluster_cardIDs[similarityID]))
        this_level_cluster_cardIDs.append(list(cardID_set))
    return this_level_cluster_cardIDs


def display_clustering_metrics(similarity_metric, clusters_IDgroups_list, clusters_cardIDs_list,
                              hierarchy_level):
    
    cluster_IDgroups_sizes = np.array([len(_clu) for _clu in clusters_IDgroups_list])
    cluster_cardIDs_sizes = np.array([len(_clu) for _clu in clusters_cardIDs_list])
    
    fig, ax = plt.subplots(1,4, figsize=(8, 1.5))
    titlesize=9
    ax[0].imshow(similarity_metric, vmin=0, vmax=1, cmap='gnuplot2')
    ax[0].set_xlabel('ID')
    ax[0].set_ylabel('ID')
    ax[0].set_title('Level '+str(hierarchy_level) +'\nSimilarity Metric', size = titlesize)
    ax[1].hist(similarity_metric.flatten(), bins=100)
    ax[1].set_xlabel('ID overlap')
    ax[1].set_ylabel('ID Counts')
    ax[1].set_yscale('log')
    ax[2].hist(cluster_IDgroups_sizes.flatten(), bins=20)
    ax[2].set_xlabel('Number of IDs')
    ax[2].set_ylabel('New Cluster Counts')
    ax[2].set_yscale('log')
    ax[3].hist(cluster_cardIDs_sizes.flatten(), bins=20)
    ax[3].set_xlabel('Number of cards')
    ax[3].set_ylabel('New Cluster Counts')
    ax[3].set_yscale('log')
    plt.subplots_adjust(wspace=0.7)
    plt.show()

# %%
def get_cluster_hierarchy(knowledgeGraph, 
                          max_num_hierarchy_levels=20,
                          meta_cluster_size_scaling=1.0,  # Doesn't seem to matter too much? 0.1 to 2.0 mostly works
                              # But smaller numbers give more well defined categories, that get combined more slowly
                          target_rms_combination_size=2.75,  # Basically how large should cluster of objects be at each level? 
                          target_number_of_combination_depth=5.5, # How deeply to cluster everthing
                          verbose=False):
    """
    Function for extracting clusters hierarchically from small to large, based on card and cluster similarity
    """
    
    # want meta_cluster_size_scaling to be large enough so that we converge quickly
    # but also small enough that some cards don't get put in clusters if they are really outliers. 

    target_number_large_clusters = len(knowledgeGraph.cards.keys()) / (target_rms_combination_size ** target_number_of_combination_depth)
    if verbose:
        print('Targeting this many large clusters:', target_number_large_clusters)
    large_cluster_number_threshold = target_number_large_clusters
    

    # Get level 0 card clusters from card ID lists, as if they were the result of some previous computation.  
    # List of similarity metric IDs in resulting groups
    prev_significant_clusters_IDgroups_list = [[_id] for _id in list(range(len(knowledgeGraph.cards.keys())))]
    # List of cards in the resulting groups 
    prev_significant_clusters_cardIDs_list = prev_significant_clusters_IDgroups_list.copy()
    # Embedding vector for each group 
    prev_emb_vec_list = [knowledgeGraph.cards[cardID].embedding_vector_trimmed for cardID in list(range(len(knowledgeGraph.cards.keys())))]
    
    # storage arrays 
    hierarchy_of_significant_clusters_IDgroups_list = []
    hierarchy_of_significant_clusters_cardIDs_list = []
    hierarchy_of_emb_vec_lists = []
    hierarchy_of_similarity_metrics = []
    
    for hierarchy_level in range(max_num_hierarchy_levels):  
        print('Calculating level ', hierarchy_level, ' with target size', meta_cluster_size_scaling) 
        
        # Adjust cluster size target based on how much we combined things last time
        prev_cluster_sizes = np.array([len(clu) for clu in prev_significant_clusters_IDgroups_list])
        combination_sizes = prev_cluster_sizes[np.where(prev_cluster_sizes > 1)]
        if len(combination_sizes) > 0:
            rms_combination_size = np.sqrt(np.average(combination_sizes **2))
            meta_cluster_size_scaling *= target_rms_combination_size/rms_combination_size  # adjust size to target some combination rate 
        else:
            rms_combination_size = 1.0
        
        if verbose:
            print('  RMS combnation size:', rms_combination_size)
        prev_emb_vec_list = get_emb_vec_list_from_cluster_cardIDs(prev_significant_clusters_cardIDs_list, knowledgeGraph)
        
        if verbose:
            print('  Calculating similarity metric...')
        prev_similarity_metric = get_similarity_metric_from_emb_vec_list(prev_emb_vec_list)    
            
        if verbose:
            print('  Calculating clustering...')
        new_significant_clusters_IDgroups_list = get_best_clusters_with_desired_size(prev_similarity_metric,
                                                 meta_cluster_size_scaling=meta_cluster_size_scaling)
        new_significant_clusters_cardIDs_list = get_new_cluster_cardIDs(new_significant_clusters_IDgroups_list, prev_significant_clusters_cardIDs_list)
        prev_num_clusters = len(prev_significant_clusters_IDgroups_list)
        new_num_clusters = len(new_significant_clusters_IDgroups_list)
        
        # Check overall hierarchy structure relative to cardIDs, to see if we should stop clustering 
        new_cluster_sizes = np.array([len(significant_cluster) for significant_cluster 
                                  in new_significant_clusters_cardIDs_list])
        rms_new_cluster_size = np.sqrt(np.mean(new_cluster_sizes ** 2))
        num_new_relatively_large_clusters = len(np.where(new_cluster_sizes >= rms_new_cluster_size)[0])  
            # This is at minimum 1 if we have a huge cluster and many small ones, 
            # but if things are not well separated, there will be many.
            # so when this reaches 1 is a good place to stop 
            
        # save previous level
        hierarchy_of_significant_clusters_IDgroups_list.append(prev_significant_clusters_IDgroups_list)
        hierarchy_of_significant_clusters_cardIDs_list.append(prev_significant_clusters_cardIDs_list)
        hierarchy_of_emb_vec_lists.append(prev_emb_vec_list)
        hierarchy_of_similarity_metrics.append(prev_similarity_metric)
        
        # now update parameters to use for next round 
        prev_significant_clusters_IDgroups_list = new_significant_clusters_IDgroups_list
        prev_significant_clusters_cardIDs_list = new_significant_clusters_cardIDs_list 
            
        if verbose:
            print('  Number of relatively large clusters:', num_new_relatively_large_clusters)
            display_clustering_metrics(prev_similarity_metric,
                                       prev_significant_clusters_IDgroups_list,
                                       prev_significant_clusters_cardIDs_list,
                                       hierarchy_level)
        
        if ((new_num_clusters == 1) or  # We have 1 cluster left total 
            (prev_num_clusters == new_num_clusters) or  # we didn't reduce the number of clusters last round
            (num_new_relatively_large_clusters <= large_cluster_number_threshold)):  # we have a pretty skewed distribution of clusters, one big one 
            if verbose:
                print('Completed with', new_num_clusters, ' final clusters.')
            break # we are done 
        
    cluster_hierarchy_meta_data = [hierarchy_of_significant_clusters_IDgroups_list, 
            hierarchy_of_significant_clusters_cardIDs_list,
            hierarchy_of_emb_vec_lists,
            hierarchy_of_similarity_metrics]
    
    return cluster_hierarchy_meta_data

# %%
# Some functions to report useful information output by clustering

def extra_3space(num):
    return "".join([' ']*(3*num))
    
def get_text_emb_vec_overlap_with_knowledgeGraph_short(emb_vec, knowledgeGraph, max_print=3):

    # Overlap over nodes
    overlap_dict_nodes = knowledgeGraph.get_dict_of_emb_vec_inner_product_over_nodes(emb_vec)
    sorted_node_titles, sorted_node_overlaps = get_dict_items_sorted_by_decreasing_value(overlap_dict_nodes)
    
    # Overlap over cards
    # overlap_dict_cards = knowledgeGraph.get_dict_of_emb_vec_inner_product_over_cards(emb_vec)
    # sorted_cardIDs, sorted_card_overlaps = get_dict_items_sorted_by_decreasing_value(overlap_dict_cards)
    
    return ", ".join([node_title for node_title in sorted_node_titles[0:max_print]])

def get_text_emb_vec_short(emb_vec, knowledgeGraph, max_print=3):

    # Direct embedding vector 
    sorted_node_titles, sorted_node_overlaps = get_dict_items_sorted_by_decreasing_value(emb_vec)
    
    return ", ".join([node_title for node_title in sorted_node_titles[0:max_print]])

def display_cluster_hierarchy_process_of_calculation(cluster_hierarchy_meta_data):
    """
    Displays calculations during creating clusters and topics.
        Things like the similarity metric, overlap histogram, and cluster size histograms 
    """
    
    [hierarchy_of_significant_clusters_IDgroups_list, 
     hierarchy_of_significant_clusters_cardIDs_list,
     hierarchy_of_emb_vec_lists,
     hierarchy_of_similarity_metrics]  = cluster_hierarchy_meta_data

    # Display all the cluster hierarchies    
    for hierarchy_level in range(len(hierarchy_of_similarity_metrics)):
        display_clustering_metrics(hierarchy_of_similarity_metrics[hierarchy_level], 
                                   hierarchy_of_significant_clusters_IDgroups_list[hierarchy_level], 
                                   hierarchy_of_significant_clusters_cardIDs_list[hierarchy_level],
                                  hierarchy_level)
        
def display_cluster_hierarchy_major_topics(cluster_hierarchy_meta_data, max_levels_to_display=5, max_print=5):
    """
    Displays text summarizing the clusters and topics in the clusters, from large to small
        Only displays clusters with large size compared to others (determined by RMS size)
    """
    fraction_of_rms_considered_relatively_large = 0.5
    
    def get_relatively_large_cluster_inds(hierarchy_of_significant_clusters_cardIDs_list, hierarchy_level):
        clusters_cardIDs_list = hierarchy_of_significant_clusters_cardIDs_list[hierarchy_level]
        cluster_cardIDs_sizes = np.array([len(_clu) for _clu in clusters_cardIDs_list])
        rms_cluster_size = np.sqrt(np.mean(cluster_cardIDs_sizes ** 2))
        relatively_large_cluster_inds = np.where(cluster_cardIDs_sizes >= fraction_of_rms_considered_relatively_large*rms_cluster_size)[0]
        return relatively_large_cluster_inds
    
    [hierarchy_of_significant_clusters_IDgroups_list, 
     hierarchy_of_significant_clusters_cardIDs_list,
     hierarchy_of_emb_vec_lists,
     hierarchy_of_similarity_metrics]  = cluster_hierarchy_meta_data
    
    num_hierarchy_levels = len(hierarchy_of_significant_clusters_IDgroups_list)

    for reverse_level in range(max_levels_to_display): # start from largest and go backwards 
        hierarchy_level = num_hierarchy_levels - reverse_level - 1
        relatively_large_cluster_inds = get_relatively_large_cluster_inds(hierarchy_of_significant_clusters_cardIDs_list, 
                                                                          hierarchy_level)
        print('Level:', hierarchy_level)
        for _clusterInd in relatively_large_cluster_inds:
            cluster_emb_vec = hierarchy_of_emb_vec_lists[hierarchy_level][_clusterInd]
            cluster_cardIDs_list = hierarchy_of_significant_clusters_cardIDs_list[hierarchy_level][_clusterInd]
            print_text_overlap = get_text_emb_vec_overlap_with_knowledgeGraph_short(cluster_emb_vec, kGraph, max_print=max_print)
            print_text_vec = get_text_emb_vec_short(cluster_emb_vec, kGraph, max_print=max_print)
            print('   Cluster ID:', _clusterInd, " Size:", len(cluster_cardIDs_list), ' Overlap Topics:', print_text_overlap,' -----', print_text_vec)
        print('')
        
def get_family_of_cluster(cluster_hierarchy_meta_data, target_hierarchy_level, target_cluster_ID):
    """
    Displays text summarizing the clusters and topics in the clusters, from large to small
        Only displays clusters with large size compared to others (determined by RMS size)
    """
    
    [hierarchy_of_significant_clusters_IDgroups_list, 
     hierarchy_of_significant_clusters_cardIDs_list,
     hierarchy_of_emb_vec_lists,
     hierarchy_of_similarity_metrics]  = cluster_hierarchy_meta_data
    
    num_hierarchy_levels = len(hierarchy_of_significant_clusters_IDgroups_list)
    
    # Get children clusters
    child_clusters_IDs = list(hierarchy_of_significant_clusters_IDgroups_list[target_hierarchy_level][target_cluster_ID])
    
    # Get parent clusters
    if target_hierarchy_level + 1 <= num_hierarchy_levels - 1:
        # Parents
        possible_parent_cluster_IDgroups_list = hierarchy_of_significant_clusters_IDgroups_list[target_hierarchy_level + 1]
        parent_clusters_IDs = [_IDgroup_ind for _IDgroup_ind, _IDgroup in enumerate(possible_parent_cluster_IDgroups_list) 
                              if target_cluster_ID in _IDgroup]
        # Siblinbs
        list_of_sibling_sets = [set(_IDgroup) for _IDgroup_ind, _IDgroup in enumerate(possible_parent_cluster_IDgroups_list) 
                              if target_cluster_ID in _IDgroup]
        sibling_clusters_IDs = set()
        for sibling_set in list_of_sibling_sets:
            sibling_clusters_IDs.update(sibling_set)
        sibling_clusters_IDs.remove(target_cluster_ID)
        sibling_clusters_IDs = list(sibling_clusters_IDs)
            
    else:
        parent_clusters_IDs = []
        sibling_clusters_IDs = []
    
    return child_clusters_IDs, parent_clusters_IDs, sibling_clusters_IDs
    

def display_cluster_hierarchy_of_cluster(cluster_hierarchy_meta_data, target_hierarchy_level, target_cluster_ID, max_print=4):
    
    def display_clusters(cluster_inds, hierarchy_level, extra_spaces):
        for _clusterInd in cluster_inds:
            cluster_emb_vec = hierarchy_of_emb_vec_lists[hierarchy_level][_clusterInd]
            cluster_cardIDs_list = hierarchy_of_significant_clusters_cardIDs_list[hierarchy_level][_clusterInd]
            print_text_overlap = get_text_emb_vec_overlap_with_knowledgeGraph_short(cluster_emb_vec, kGraph, max_print=max_print)
            print_text_vec = get_text_emb_vec_short(cluster_emb_vec, kGraph, max_print=max_print)
            print(extra_3space(extra_spaces), 'Level:', hierarchy_level, ' ID:', _clusterInd, 
                  " Size:", len(cluster_cardIDs_list), ' Topics:', print_text_overlap,' -----', print_text_vec)
        
    [hierarchy_of_significant_clusters_IDgroups_list, 
     hierarchy_of_significant_clusters_cardIDs_list,
     hierarchy_of_emb_vec_lists,
     hierarchy_of_similarity_metrics]  = cluster_hierarchy_meta_data
    
    num_hierarchy_levels = len(hierarchy_of_significant_clusters_IDgroups_list)

    children, parents, siblings = get_family_of_cluster(cluster_hierarchy_meta_data, target_hierarchy_level, target_cluster_ID)
    children_hierarchy_level = target_hierarchy_level - 1
    parent_hierarchy_level = target_hierarchy_level + 1
    
    # Display things, if they exist 
    if parent_hierarchy_level < num_hierarchy_levels - 1:
        
        # Get grandparents and display 
        grandparents_set = set()
        for parent in parents:
            _, grandparents, _ = get_family_of_cluster(cluster_hierarchy_meta_data, parent_hierarchy_level, parent)
            grandparents_set.update(set(grandparents))
        grandparents = list(grandparents_set)
        print('Grandparents')
        for grandparent in grandparents:
            display_clusters([grandparent], parent_hierarchy_level + 1, 0)
        
        # Display parents 
        print('Parents')
        display_clusters(parents, parent_hierarchy_level, 0)
    
    # Display siblings and self 
    print(extra_3space(1), 'Siblings')
    display_clusters(siblings, target_hierarchy_level,1)
    print(extra_3space(1), 'Self')
    display_clusters([target_cluster_ID], target_hierarchy_level,1)
    
    # Get children and grandchildren 
    if children_hierarchy_level >= 0:
        print(extra_3space(2), 'Children')
        for child in children:
            display_clusters([child], children_hierarchy_level, 2)
            grandchildren_hierarchy_level = children_hierarchy_level - 1
            if grandchildren_hierarchy_level >= 0:
                print(extra_3space(3), 'Grandchildren')
                grandchildren, *_ = get_family_of_cluster(cluster_hierarchy_meta_data, children_hierarchy_level, child)
                display_clusters(grandchildren, grandchildren_hierarchy_level, 3)

# %%
cluster_hierarchy_meta_data = get_cluster_hierarchy(kGraph, verbose=False)
# Out:
# Calculating level  0  with target size 1.0
#   Clusters identified:  348
# Calculating level  1  with target size 1.0
#   Clusters identified:  197
# Calculating level  2  with target size 0.9641210024070711
#   Clusters identified:  117
# Calculating level  3  with target size 0.9010462565578808
#   Clusters identified:  76
# Calculating level  4  with target size 0.8009241688063995
#   Clusters identified:  54
# Calculating level  5  with target size 0.8404185653491886
#   Clusters identified:  40
# Calculating level  6  with target size 0.8526070064089959
#   Clusters identified:  33
# Calculating level  7  with target size 0.9572072202109574
#   Clusters identified:  29
# Calculating level  8  with target size 0.99492338700607
#   Clusters identified:  26
# Calculating level  9  with target size 0.8652116000847972
#   Clusters identified:  22

# %%
# Display context of whole graph clustering 

display_cluster_hierarchy_major_topics(cluster_hierarchy_meta_data, max_levels_to_display=5)
display_cluster_hierarchy_process_of_calculation(cluster_hierarchy_meta_data)
# Out:
# Level: 9
#    Cluster ID: 0  Size: 251  Overlap Topics: Measurement, Prediction, Modeling, Metric, Architecture  ----- T-SNE, T-Sne, Grokking, Latent Variable Model, Mechanistic Interpretability
#    Cluster ID: 2  Size: 54  Overlap Topics: Measurement, Distribution, Gaussian, Data Analysis, Entropy  ----- T-SNE, T-Sne, Odds Ratio, Similarity, Pass@k
#    Cluster ID: 4  Size: 98  Overlap Topics: Paper, Information, Metric, Education, CD Index  ----- Citation, Ratio, Numpy, Numeracy, Motivated Numeracy
#    Cluster ID: 5  Size: 95  Overlap Topics: Environment, Economics, Biology, Business, Ecology  ----- Nuclear, Eric Reis, Lean Startup, Great Barrier Reef, Entrepreneurship
#
# Level: 8
#    Cluster ID: 0  Size: 150  Overlap Topics: Measurement, Metric, Goal, Distribution, Entropy  ----- T-SNE, T-Sne, Latent Variable Model, Similarity, Grokking
#    Cluster ID: 1  Size: 112  Overlap Topics: Architecture, Measurement, Training, Interpretability, Progress  ----- Grokking, Mechanistic Interpretability, Pass@k, Amazon, Macroscopic
#    Cluster ID: 3  Size: 98  Overlap Topics: Paper, Information, Metric, Education, CD Index  ----- Citation, Ratio, Numpy, Numeracy, Motivated Numeracy
#    Cluster ID: 4  Size: 95  Overlap Topics: Environment, Economics, Biology, Business, Ecology  ----- Nuclear, Eric Reis, Lean Startup, Great Barrier Reef, Entrepreneurship
#    Cluster ID: 11  Size: 28  Overlap Topics: Prediction, Data Science, Paper, Architecture, Metric  ----- Non-Parametric, Parametric, Adaboost, XGboost, Boosting
#    Cluster ID: 13  Size: 54  Overlap Topics: Measurement, Distribution, Gaussian, Data Analysis, Entropy  ----- T-SNE, T-Sne, Odds Ratio, Similarity, Pass@k
#
# Level: 7
#    Cluster ID: 0  Size: 107  Overlap Topics: Measurement, Metric, Goal, Entropy, Distribution  ----- T-SNE, T-Sne, Similarity, Grokking, Look Ahead
#    Cluster ID: 1  Size: 98  Overlap Topics: Paper, Information, Metric, Education, CD Index  ----- Citation, Ratio, Numpy, Numeracy, Motivated Numeracy
#    Cluster ID: 2  Size: 72  Overlap Topics: Architecture, Training, Interpretability, Progress, Article  ----- Grokking, Mechanistic Interpretability, Amazon, Macroscopic, Rewiring
#    Cluster ID: 3  Size: 104  Overlap Topics: Architecture, Measurement, Training, Interpretability, Progress  ----- Grokking, Mechanistic Interpretability, Pass@k, Amazon, Macroscopic
#    Cluster ID: 4  Size: 95  Overlap Topics: Environment, Economics, Biology, Business, Ecology  ----- Nuclear, Eric Reis, Lean Startup, Great Barrier Reef, Entrepreneurship
#    Cluster ID: 11  Size: 28  Overlap Topics: Prediction, Data Science, Paper, Architecture, Metric  ----- Non-Parametric, Parametric, Adaboost, XGboost, Boosting
#    Cluster ID: 12  Size: 40  Overlap Topics: Gaussian, Entropy, Distribution, Measurement, Reconstruction  ----- T-SNE, T-Sne, Similarity, Grokking, Latent Variable Model
#    Cluster ID: 14  Size: 38  Overlap Topics: Modeling, Sampling, Latent Space, Inference, Representation  ----- Latent Variable Model, Flow Model, Multi-dimensional Flow Model, Deep Unsupervised Learning, T-SNE
#    Cluster ID: 15  Size: 54  Overlap Topics: Measurement, Distribution, Gaussian, Data Analysis, Entropy  ----- T-SNE, T-Sne, Odds Ratio, Similarity, Pass@k
#    Cluster ID: 25  Size: 22  Overlap Topics: Data Science, Prediction, Measurement, Modeling, Architecture  ----- Equation of Motion, Active Matter, Grokking, Non-Parametric, Parametric
#
# Level: 6
#    Cluster ID: 0  Size: 35  Overlap Topics: Paper, Information, Metric, CD Index, Experiment  ----- Citation, Ratio, Numeracy, Motivated Numeracy, Problem Creator
#    Cluster ID: 1  Size: 61  Overlap Topics: Architecture, Measurement, Prediction, Paper, Embedding  ----- Pass@k, Metric, Bert, Nlp, T-Sne
#    Cluster ID: 2  Size: 78  Overlap Topics: Measurement, Metric, Entropy, Distribution, Goal  ----- T-SNE, T-Sne, Similarity, Look Ahead, State Space
#    Cluster ID: 3  Size: 54  Overlap Topics: Measurement, Distribution, Gaussian, Data Analysis, Entropy  ----- T-SNE, T-Sne, Odds Ratio, Similarity, Pass@k
#    Cluster ID: 4  Size: 73  Overlap Topics: Paper, Metric, Information, CD Index, Python  ----- Citation, Ratio, Numpy, Problem Creator, Problem Solver
#    Cluster ID: 5  Size: 61  Overlap Topics: Network, Architecture, Prediction, Resource, Engineering  ----- Grokking, State Space, Tradeoff, Human, Mechanistic Interpretability
#    Cluster ID: 6  Size: 41  Overlap Topics: Economics, Business, Intellectual Property, Social Sciences, Patent  ----- Eric Reis, Lean Startup, Entrepreneurship, Management, Conservation
#    Cluster ID: 7  Size: 70  Overlap Topics: Environment, Biology, Economics, Ecology, Business  ----- Nuclear, Eric Reis, Lean Startup, Great Barrier Reef, Entrepreneurship
#    Cluster ID: 8  Size: 64  Overlap Topics: Architecture, Training, Interpretability, Progress, Article  ----- Grokking, Mechanistic Interpretability, Amazon, Macroscopic, Bert
#    Cluster ID: 9  Size: 53  Overlap Topics: Network, Prediction, Architecture, Measurement, Metric  ----- Look Ahead, State Space, Tradeoff, Value Function, Human
#    Cluster ID: 10  Size: 38  Overlap Topics: Modeling, Sampling, Latent Space, Inference, Representation  ----- Latent Variable Model, Flow Model, Multi-dimensional Flow Model, Deep Unsupervised Learning, T-SNE
#    Cluster ID: 11  Size: 28  Overlap Topics: Prediction, Data Science, Paper, Architecture, Metric  ----- Non-Parametric, Parametric, Adaboost, XGboost, Boosting
#    Cluster ID: 12  Size: 40  Overlap Topics: Gaussian, Entropy, Distribution, Measurement, Reconstruction  ----- T-SNE, T-Sne, Similarity, Grokking, Latent Variable Model
#    Cluster ID: 13  Size: 59  Overlap Topics: Python, Logic, Data Structure, Problem Solving, Programming  ----- Numpy, Diagonalizable, Hermitian Matrix, Minor, Laplace
#    Cluster ID: 29  Size: 22  Overlap Topics: Data Science, Prediction, Measurement, Modeling, Architecture  ----- Equation of Motion, Active Matter, Grokking, Non-Parametric, Parametric
#
# Level: 5
#    Cluster ID: 0  Size: 43  Overlap Topics: Python, Data Structure, Programming, Problem Solving, Function  ----- Numpy, Minor, Laplace, Tradeoff, Array
#    Cluster ID: 1  Size: 50  Overlap Topics: Architecture, Prediction, Paper, Token, Data Science  ----- Bert, Nlp, Grokking, BERT, Non-Parametric
#    Cluster ID: 2  Size: 62  Overlap Topics: Environment, Biology, Ecology, Climate Change, Year  ----- Nuclear, Great Barrier Reef, Landfill, Immunology, Geological Era
#    Cluster ID: 3  Size: 53  Overlap Topics: Architecture, Training, Interpretability, Progress, Article  ----- Grokking, Mechanistic Interpretability, Amazon, Macroscopic, Bert
#    Cluster ID: 4  Size: 40  Overlap Topics: Network, Prediction, Architecture, Input, Problem Solving  ----- State Space, Tradeoff, Human, NFLT, Grokking
#    Cluster ID: 5  Size: 31  Overlap Topics: Modeling, Latent Space, Representation, Prediction, Flow  ----- Latent Variable Model, Flow Model, Multi-dimensional Flow Model, Deep Unsupervised Learning, NICE Paper (2014)
#    Cluster ID: 6  Size: 39  Overlap Topics: Architecture, Paper, Prediction, Embedding, Token  ----- Bert, Layers, BERT, Grokking, T-Sne
#    Cluster ID: 7  Size: 26  Overlap Topics: Measurement, Distribution, Gaussian, Data Analysis, Entropy  ----- T-SNE, T-Sne, Similarity, Kulback Liebler, Bayesian Inference
#    Cluster ID: 8  Size: 56  Overlap Topics: Architecture, Measurement, Prediction, Paper, Evaluation  ----- Pass@k, Metric, Bert, Nlp, T-Sne
#    Cluster ID: 9  Size: 19  Overlap Topics: Prediction, Data Science, Algorithm, Model, Science and Technology  ----- Non-Parametric, Parametric, Adaboost, XGboost, Boosting
#    Cluster ID: 10  Size: 30  Overlap Topics: Measurement, Modeling, Reconstruction, Distribution, Entropy  ----- T-SNE, T-Sne, Grokking, Latent Variable Model, Deep Unsupervised Learning
#    Cluster ID: 11  Size: 42  Overlap Topics: Python, Logic, Data Structure, Programming, Algebra  ----- Numpy, Diagonalizable, Hermitian Matrix, Array, Ring
#    Cluster ID: 12  Size: 25  Overlap Topics: Problem Solving, Optimization, Resource, Human, Engineering  ----- Tradeoff, Human, NFLT, Transfer, Neuralink 3
#    Cluster ID: 13  Size: 43  Overlap Topics: Network, Prediction, Metric, MCTS, Measurement  ----- Look Ahead, State Space, Value Function, PPO, Generalized Policy Iteration
#    Cluster ID: 14  Size: 22  Overlap Topics: Paper, Architecture, Interpretability, MLP, Engineering  ----- Grokking, Adaboost, XGboost, Boosting, Mechanistic Interpretability
#    Cluster ID: 15  Size: 14  Overlap Topics: Autoregressive Model, Masking, Paper, Neural Network, Data Processing  ----- Latent Variable Model, Masked Autoregressive Model, Recurrent Neural Network, Improving Rnn, Image Generation
#    Cluster ID: 16  Size: 29  Overlap Topics: Measurement, Distribution, Modeling, Probability, Gaussian  ----- T-Sne, Odds Ratio, T-SNE, Pass@k, Z
#    Cluster ID: 17  Size: 31  Overlap Topics: Modeling, Sampling, Latent Space, Inference, Flow  ----- Latent Variable Model, Flow Model, Multi-dimensional Flow Model, Deep Unsupervised Learning, T-SNE
#    Cluster ID: 18  Size: 25  Overlap Topics: Intellectual Property, Patent, Law, Economics, Politics  ----- Government, Agreement, Medicaid, Licensing, Right
#    Cluster ID: 19  Size: 33  Overlap Topics: Gaussian, Entropy, Distribution, Measurement, Reconstruction  ----- T-SNE, T-Sne, Similarity, Grokking, Latent Variable Model
#    Cluster ID: 20  Size: 19  Overlap Topics: Distribution, Gaussian, Measurement, Data Analysis, Entropy  ----- T-SNE, T-Sne, Similarity, Kulback Liebler, Bayesian Inference
#    Cluster ID: 21  Size: 42  Overlap Topics: Interpretability, Progress, Article, Training, Anthropic  ----- Grokking, Mechanistic Interpretability, Macroscopic, Feature, Progress
#    Cluster ID: 25  Size: 22  Overlap Topics: Data Science, Prediction, Measurement, Modeling, Architecture  ----- Equation of Motion, Active Matter, Grokking, Non-Parametric, Parametric
#    Cluster ID: 26  Size: 26  Overlap Topics: Paper, Metric, CD Index, Information, Focal Paper  ----- Citation, Ratio, Problem Creator, Problem Solver, Numeracy
#    Cluster ID: 27  Size: 16  Overlap Topics: Economics, Social Sciences, Business, Innovation, Growth  ----- Eric Reis, Lean Startup, Entrepreneurship, Management, Conservation

# %%
# Display context of a single cluster or card 

target_hierarchy_level = 1
target_cluster_ID = 3
display_cluster_hierarchy_of_cluster(cluster_hierarchy_meta_data, target_hierarchy_level, target_cluster_ID)
# Out:
# Grandparents
#  Level: 3  ID: 36  Size: 11  Topics: Python, Data Structure, Programming, Information  ----- Numpy, File, File Access, Array
#  Level: 3  ID: 23  Size: 14  Topics: Data Structure, Python, Programming, List  ----- Numpy, Array, Key-Value Pair, Finding Object
# Parents
#  Level: 2  ID: 42  Size: 7  Topics: Data Structure, Python, List, Problem Solving  ----- Numpy, Key-Value Pair, Indexing, Dict.items()
#     Siblings
#     Level: 1  ID: 250  Size: 2  Topics: Data Structure, Python, Tuple, Problem Solving  ----- Key-Value Pair, Indexing, Dict.items(), Dict
#     Level: 1  ID: 26  Size: 4  Topics: Data Structure, Python, Problem Solving, List  ----- Numpy, Numeracy, Motivated Numeracy, Mylist
#     Self
#     Level: 1  ID: 3  Size: 5  Topics: Python, Data Structure, Programming, List  ----- Numpy, Iterator, Next, Iter
#        Children
#        Level: 0  ID: 470  Size: 1  Topics: Python, Programming, Data, List  ----- Numpy, Scientific Computing, Manipulation, 3D Printing
#        Level: 0  ID: 435  Size: 1  Topics: Python, Data Structure, Problem Solving, Programming  ----- Numpy, Key-value, Scientific Computing, 3D Printing
#        Level: 0  ID: 468  Size: 1  Topics: Python, Data Structure, Programming, Object  ----- Numpy, Next, Iter, Wrapper
#        Level: 0  ID: 502  Size: 1  Topics: Python, Data Structure, Problem Solving, Programming  ----- Numpy, Mylist, Concatenation, Extend()
#        Level: 0  ID: 432  Size: 1  Topics: Python, Data Structure, Problem Solving, Programming  ----- Numpy, Numeracy, Motivated Numeracy, Scientific Computing

# %% [markdown]
# ### Explore cluster overlaps

# %%
# Get a list of embedding vectors from all clusters, with IDs

def get_all_unique_cluster_emb_vecs(cluster_hierarchy_meta_data):
    
    # This also removes non-unique clusters (ones that appear unchanged at multiple hierarchy levels, 
    # and it replaces them with only the lowest hierarchy where they appear. 
    
    [hierarchy_of_significant_clusters_IDgroups_list, 
     hierarchy_of_significant_clusters_cardIDs_list,
     hierarchy_of_emb_vec_lists,
     hierarchy_of_similarity_metrics]  = cluster_hierarchy_meta_data
    
    significant_clusters_unique_tuple_id_list = [] # for checking if this exact cluster is already found        
    all_unique_cluster_emb_vecs = {}
    for hierarchy_level in range(len(hierarchy_of_emb_vec_lists)):  # goes from low to high 
        
        unique_tuple_cardID_list_this_level = {(hierarchy_level, cluster_ID): tuple(sorted(cardIDs_list)) for cluster_ID, cardIDs_list 
                                       in enumerate(hierarchy_of_significant_clusters_cardIDs_list[hierarchy_level])}
        
        cluster_emb_vecs_this_level = {(hierarchy_level, cluster_ID): emb_vec for cluster_ID, emb_vec 
                                       in enumerate(hierarchy_of_emb_vec_lists[hierarchy_level]) 
                                      if not (unique_tuple_cardID_list_this_level[(hierarchy_level, cluster_ID)] 
                                              in significant_clusters_unique_tuple_id_list)}
        all_unique_cluster_emb_vecs.update(cluster_emb_vecs_this_level)
        
        # Update list of unique ideas not to use in future. 
        significant_clusters_unique_tuple_id_list.extend(list(unique_tuple_cardID_list_this_level.values()))
    
    return all_unique_cluster_emb_vecs

def get_all_card_counts_over_unique_clusters(cluster_hierarchy_meta_data, all_unique_cluster_emb_vecs, knowledgeGraph):
    
    # This also removes non-unique clusters (ones that appear unchanged at multiple hierarchy levels, 
    # and it replaces them with only the lowest hierarchy where they appear. 
    
    [hierarchy_of_significant_clusters_IDgroups_list, 
     hierarchy_of_significant_clusters_cardIDs_list,
     hierarchy_of_emb_vec_lists,
     hierarchy_of_similarity_metrics]  = cluster_hierarchy_meta_data
    
    all_card_counts = [{k: 0.0 for k in list(knowledgeGraph.cards.keys())} for _ in range(len(hierarchy_of_similarity_metrics))]
    
    for hierarchy_level, cluster_ID in all_unique_cluster_emb_vecs.keys():
        cluster_cardIDs_list = hierarchy_of_significant_clusters_cardIDs_list[hierarchy_level][cluster_ID]
        for _cardID in cluster_cardIDs_list:
            all_card_counts[hierarchy_level][_cardID] += 1.0
        
    return all_card_counts

all_unique_cluster_emb_vecs = get_all_unique_cluster_emb_vecs(cluster_hierarchy_meta_data)
all_card_counts = get_all_card_counts_over_unique_clusters(cluster_hierarchy_meta_data, all_unique_cluster_emb_vecs, kGraph)

display_dict_sorted_by_decreasing_value(all_unique_cluster_emb_vecs[(0,76)])
display_dict_sorted_by_decreasing_value(all_card_counts[6])
# Out:
# [('Random Distribution', 0.12964127985537088),
#  ('Continuous Data', 0.1226581807343238),
#  ('Grokking', 0.06418630605916346),
#  ('Subspaces', 0.05984949809968133),
#  ('Latent Variable Model', 0.05360491763471948),
#  ('Flow Model', 0.053316390300952705),
#  ('Mechanistic Interpretability', 0.040788823119029566),
#  ('Layers', 0.0221376935408529),
#  ('Generalization', 0.019046577487505687),
#  ('Deep Unsupervised Learning', 0.01522283612665451)]
# [(253, 5.0),
#  (138, 5.0),
#  (42, 5.0),
#  (99, 4.0),
#  (445, 4.0),
#  (392, 4.0),
#  (242, 4.0),
#  (278, 4.0),
#  (192, 4.0),
#  (276, 4.0)]
